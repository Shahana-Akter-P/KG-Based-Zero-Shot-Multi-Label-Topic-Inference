# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/keywords/Keyword_Medical.json
# /kaggle/input/keywords/Keyword_Canon.json
# /kaggle/input/keywords/Keyword_Creative.json
# /kaggle/input/keywords/Keyword_Apex.json
# /kaggle/input/keywords/Keyword_Apex 1.json
# /kaggle/input/keywords/Keyword_Nokia.json
# /kaggle/input/keywords/Keyword_News.json
# /kaggle/input/keywords/Keyword_Nikon.json
# /kaggle/input/zstikg/NewsConcept Data-set.json
# /kaggle/input/zstikg/DVD playerData-set.json
# /kaggle/input/zstikg/MedicalConcept Data-set.json
# /kaggle/input/zstikg/Cellular phone Data-set.json
# /kaggle/input/zstikg/Digital camera2 Data-set.json
# /kaggle/input/zstikg/Mp3 playerData-set.json
# /kaggle/input/zstikg/Digital camera1 Data-set.json

# %%
# ============================================================================
# PART 1: INSTALLATION AND SETUP
# ============================================================================

# Install required packages
# !pip install dspy-ai huggingface_hub networkx sentence-transformers pandas --quiet

print("✓ Packages installed successfully!")
# Out:
# ✓ Packages installed successfully!

# %%
# ============================================================================
# PART 1: IMPORTS
# ============================================================================

import json
import networkx as nx
from typing import List, Dict, Set, Tuple
import dspy
from sentence_transformers import SentenceTransformer
import numpy as np
from collections import defaultdict
import pandas as pd
import os
from huggingface_hub import InferenceClient

print("✓ All imports successful!")
# Out:
# ✓ All imports successful!

# %%
# ============================================================================
# STEP 2: CONFIGURE HUGGING FACE WITH DSPY.LM (PROPER WAY)
# ============================================================================

os.environ['HUGGINGFACE_API_KEY'] = 'KEY'

# Use DSPy's built-in LM class with the correct prefix
lm = dspy.LM(
    model='huggingface/meta-llama/Llama-3.1-8B-Instruct',
    api_key=os.environ['HUGGINGFACE_API_KEY'],
    max_tokens=12000,
    temperature=0.3
)

dspy.settings.configure(lm=lm)
print("✓ Llama-3.1-8B-Instruct configured successfully!")
# Out:
# ✓ Llama-3.1-8B-Instruct configured successfully!

# %%
# ============================================================================
# PART 1: DATA LOADING FUNCTION
# ============================================================================

def load_json_data(filepath: str) -> List[Dict]:
    """
    Load JSON data from file
    
    Expected format:
    [
        {
            "Article Title": [],
            "Article Text": "text here...",
            "Concept": ["concept1", "concept2"]
        },
        ...
    ]
    """
    with open(filepath, 'r', encoding='utf-8') as f:
        data = json.load(f)
    
    print(f"✓ Loaded {len(data)} documents from {filepath}")
    return data

# Test with sample data
sample_data = [
    {
        "Article Title": [],
        "Article Text": "excellent phone, excellent service.",
        "Concept": []
    },
    {
        "Article Title": [],
        "Article Text": "i am a business user who heavily depend on mobile service.",
        "Concept": ["service"]
    }
]

print("✓ Sample data ready for testing")
print(f"  Sample has {len(sample_data)} documents")
# Out:
# ✓ Sample data ready for testing
#   Sample has 2 documents

# %%
# ============================================================================
# LOAD ONE SPECIFIC DATASET
# ============================================================================

# Choose which dataset you want to work with:
# Option 1: Cellular phone
filepath = '/kaggle/input/zstikg/Mp3 playerData-set.json'

# Option 2: News
# filepath = '/kaggle/input/zsltikg/NewsConcept Data-set.json'

# Option 3: Medical
# filepath = '/kaggle/input/zsltikg/MedicalConcept Data-set.json'

# Load the data
data = load_json_data(filepath)

print(f"✓ Loaded {len(data)} documents")
print(f"\nFirst document preview:")
print(f"  Keys: {list(data[0].keys())}")
print(f"  Text: {data[0].get('Article Text', '')}...")
print(f"  Concepts: {data[0].get('Concept', [])}")
# Out:
# ✓ Loaded 1811 documents from /kaggle/input/zstikg/Mp3 playerData-set.json
# ✓ Loaded 1811 documents
#
# First document preview:
#   Keys: ['Article Title', 'Article Text', 'Concept']
#   Text:  a quick update to the new zen nx ?
# ...
#   Concepts: []

# %%
# ============================================================================
# PROCESS YOUR ALL THE ARTICLES
# ============================================================================

print("=" * 80)
print("PROCESSING ALL THE ARTICLES")
print("=" * 80)

# data is now correctly loaded as a list of dicts
individual_articles = []

for idx, item in enumerate(data):
    article = {
        'id': idx,
        'Article Text': item['Article Text'],
        #'Concept': item['Concept'] if item['Concept'] else []
    }
    individual_articles.append(article)

print(f"\n✓ Created list of {len(individual_articles)} individual articles")

# Show first 3
print(f"\nFirst 3 articles:")
print("-" * 80)
for i in range(min(3, len(individual_articles))):
    article = individual_articles[i]
    print(f"\nArticle {article['id']}:")
    print(f"  Text: {article['Article Text'][:80]}...")
    #print(f"  Concepts: {article['Concept']}")
# Out:
# ================================================================================
# PROCESSING ALL THE ARTICLES
# ================================================================================
#
# ✓ Created list of 1811 individual articles
#
# First 3 articles:
# --------------------------------------------------------------------------------
#
# Article 0:
#   Text:  a quick update to the new zen nx ?
# ...
#
# Article 1:
#   Text: this is an edited review , now that i have had time to use the device .
# ...
#
# Article 2:
#   Text: while , there are flaws with the machine , the xtra gets five stars because of i...

# %%
# ============================================================================
# STEP 3: DEFINE SIGNATURES
# ============================================================================

class EntityExtractor(dspy.Signature):
    """Extract key entities from the given text. Extracted entities are nouns, 
    verbs, or adjectives, particularly regarding sentiment. This is for an 
    extraction task, please be thorough and accurate to the reference text.
    
    Return ONLY a valid JSON list format: ["entity1", "entity2", "entity3"]
    """
    
    text = dspy.InputField(desc="The text to extract entities from")
    entities = dspy.OutputField(desc="List of extracted entities in JSON format")

class RelationExtractor(dspy.Signature):
    """Extract subject-predicate-object triples from the assistant message. 
    A predicate (1-3 words) defines the relationship between the subject and 
    object. Relationship may be fact or sentiment based on assistant's message. 
    Subject and object are entities. Entities provided are from the assistant 
    message and prior conversation history, though you may not need all of them. 
    This is for an extraction task, please be thorough, accurate, and faithful 
    to the reference text.
    
    Return ONLY valid JSON format: [["subject1", "predicate1", "object1"], ["subject2", "predicate2", "object2"]]
    """
    
    text = dspy.InputField(desc="The text to extract relations from")
    entities = dspy.InputField(desc="List of available entities")
    triples = dspy.OutputField(desc="List of [subject, predicate, object] triples in JSON format")

print("✓ Signatures defined")
# Out:
# ✓ Signatures defined

# %%
# ============================================================================
# STEP 4: CREATE ENTITY EXTRACTOR
# ============================================================================

class ExtractEntities(dspy.Module):
    def __init__(self):
        super().__init__()
        self.extract = dspy.ChainOfThought(EntityExtractor)
    
    def forward(self, text: str) -> List[str]:
        if not text or len(text.strip()) < 3:
            return []
            
        result = self.extract(text=text)
        
        try:
            entities_text = result.entities.strip()
            
            if '[' in entities_text and ']' in entities_text:
                start = entities_text.find('[')
                end = entities_text.rfind(']') + 1
                entities_text = entities_text[start:end]
            
            entities = json.loads(entities_text)
            
            if isinstance(entities, list):
                return [str(e).lower().strip() for e in entities if e and len(str(e).strip()) > 1]
            return []
            
        except:
            try:
                entities_text = result.entities.strip()
                if entities_text.startswith('['):
                    entities_text = entities_text[1:]
                if entities_text.endswith(']'):
                    entities_text = entities_text[:-1]
                
                entities = []
                for item in entities_text.split(','):
                    item = item.strip(' "\'\n\t')
                    if item and len(item) > 1:
                        entities.append(item.lower())
                
                return entities[:50]
            except:
                return []

entity_extractor = ExtractEntities()
print("✓ Entity Extractor created")
# Out:
# ✓ Entity Extractor created

# %%
# ============================================================================
# STEP 5: CREATE RELATION EXTRACTOR
# ============================================================================

class ExtractRelations(dspy.Module):
    def __init__(self):
        super().__init__()
        self.extract = dspy.ChainOfThought(RelationExtractor)
    
    def forward(self, text: str, entities: List[str]) -> List[Tuple[str, str, str]]:
        if not entities or not text:
            return []
        
        entities_subset = entities[:30]
        entities_str = json.dumps(entities_subset)
        
        result = self.extract(text=text, entities=entities_str)
        
        try:
            triples_text = result.triples.strip()
            
            if '[' in triples_text and ']' in triples_text:
                start = triples_text.find('[')
                end = triples_text.rfind(']') + 1
                triples_text = triples_text[start:end]
            
            triples = json.loads(triples_text)
            
            normalized_triples = []
            for triple in triples:
                if isinstance(triple, (list, tuple)) and len(triple) == 3:
                    s, p, o = triple
                    s = str(s).lower().strip()
                    p = str(p).lower().strip()
                    o = str(o).lower().strip()
                    
                    if s and p and o and s != o:
                        normalized_triples.append((s, p, o))
            
            return normalized_triples
            
        except Exception as e:
            return []

relation_extractor = ExtractRelations()
print("✓ Relation Extractor created")
# Out:
# ✓ Relation Extractor created

# %%
# ============================================================================
# CLUSTERING SIGNATURES (DEFINE FIRST!)
# ============================================================================

class ClusterValidator(dspy.Signature):
    """Verify if these entities belong in the same cluster.
    A cluster should contain entities that are the same in meaning, with different:
    - tenses, plural forms, stem forms, upper/lower cases
    Or entities with close semantic meanings.
    
    Return ONLY valid JSON format: ["entity1", "entity2", "entity3"]
    Return only entities you are confident belong together.
    If not confident, return empty list [].
    """
    
    entities = dspy.InputField(desc="Entities to validate")
    valid_cluster = dspy.OutputField(desc="Validated cluster in JSON format")

print("✓ ClusterValidator Signature defined")
# Out:
# ✓ ClusterValidator Signature defined

# %%
# ============================================================================
# SEMANTIC SIMILARITY CLUSTERING (FROM PAPER)
# ============================================================================

from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

class SemanticEntityClustering(dspy.Module):
    def __init__(self, similarity_threshold=0.75):
        super().__init__()
        self.validator = dspy.ChainOfThought(ClusterValidator)
        
        # Load embedding model (same as paper)
        print("Loading sentence transformer model...")
        self.model = SentenceTransformer('all-MiniLM-L6-v2')
        print("✓ Model loaded")
        
        self.similarity_threshold = similarity_threshold
    
    def _parse_cluster(self, text: str) -> List[str]:
        """Parse cluster from LLM response"""
        try:
            text = text.strip()
            if '[' in text and ']' in text:
                start = text.find('[')
                end = text.rfind(']') + 1
                text = text[start:end]
            
            cluster = json.loads(text)
            if isinstance(cluster, list):
                return [str(e).lower().strip() for e in cluster if e]
            return []
        except:
            return []
    
    def _get_semantic_clusters(self, entities: List[str]) -> List[List[str]]:
        """Group entities by semantic similarity using embeddings"""
        
        if len(entities) == 0:
            return []
        
        # Get embeddings for all entities
        embeddings = self.model.encode(entities)
        
        # Compute pairwise cosine similarity
        similarity_matrix = cosine_similarity(embeddings)
        
        # Find clusters using similarity threshold
        clusters = []
        remaining = set(range(len(entities)))
        
        for i in range(len(entities)):
            if i not in remaining:
                continue
            
            # Find all entities similar to this one
            cluster_indices = [i]
            remaining.discard(i)
            
            for j in range(i + 1, len(entities)):
                if j not in remaining:
                    continue
                
                # Check if similar enough
                if similarity_matrix[i][j] >= self.similarity_threshold:
                    cluster_indices.append(j)
                    remaining.discard(j)
            
            # Convert indices to entity names
            cluster = [entities[idx] for idx in cluster_indices]
            
            # Only keep clusters with 2-4 entities
            if 2 <= len(cluster) <= 4:
                clusters.append(cluster)
            elif len(cluster) == 1:
                # Keep singletons for later
                pass
        
        return clusters
    
    def forward(self, entities: List[str]) -> Dict[str, List[str]]:
        """Semantic clustering with LLM validation"""
        
        print(f"Starting semantic clustering with {len(entities)} entities...")
        print(f"  Similarity threshold: {self.similarity_threshold}")
        
        # Remove duplicates
        unique_entities = list(set(entities))
        
        # Step 1: Find semantic clusters using embeddings
        print("  Computing semantic similarities...")
        potential_clusters = self._get_semantic_clusters(unique_entities)
        
        print(f"  Found {len(potential_clusters)} potential clusters")
        
        # Step 2: Validate with LLM
        validated_clusters = {}
        cluster_id = 0
        clustered_entities = set()
        
        for cluster in potential_clusters:
            try:
                # Ask LLM to validate
                validation = self.validator(entities=json.dumps(cluster))
                validated = self._parse_cluster(validation.valid_cluster)
                
                if validated and len(validated) >= 2:
                    cluster_label = validated[0]
                    validated_clusters[cluster_label] = validated
                    
                    for entity in validated:
                        clustered_entities.add(entity)
                    
                    print(f"  ✓ Cluster {cluster_id}: {validated}")
                    cluster_id += 1
                else:
                    # LLM rejected - add as singletons
                    for entity in cluster:
                        if entity not in clustered_entities:
                            validated_clusters[entity] = [entity]
                            clustered_entities.add(entity)
            except:
                # Error - add as singletons
                for entity in cluster:
                    if entity not in clustered_entities:
                        validated_clusters[entity] = [entity]
                        clustered_entities.add(entity)
        
        # Step 3: Add all remaining entities as singletons
        for entity in unique_entities:
            if entity not in clustered_entities:
                validated_clusters[entity] = [entity]
        
        multi = sum(1 for v in validated_clusters.values() if len(v) > 1)
        print(f"✓ Semantic clustering complete: {len(validated_clusters)} total clusters")
        print(f"  Multi-entity clusters: {multi}")
        print(f"  Singleton entities: {len(validated_clusters) - multi}")
        
        return validated_clusters

# Create semantic clusterer with different thresholds
entity_clusterer_semantic = SemanticEntityClustering(similarity_threshold=0.75)
print("\n✓ Semantic Entity Clustering Module created")
# Out:
# Loading sentence transformer model...
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/pydantic/_internal/_generate_schema.py:2225: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# ✓ Model loaded
#
# ✓ Semantic Entity Clustering Module created

# %%
# ============================================================================
# FINAL KGGEN WITH SEMANTIC CLUSTERING
# ============================================================================

class KGGenSemantic:
    def __init__(self, similarity_threshold=0.75):
        self.entity_extractor = entity_extractor
        self.relation_extractor = relation_extractor
        self.entity_clusterer = SemanticEntityClustering(similarity_threshold=similarity_threshold)
        self.graph = nx.DiGraph()
        self.entity_clusters = {}
        
    def generate_from_json(self, json_data: List[Dict], max_docs: int = None) -> nx.DiGraph:
        """Generate KG from JSON dataset"""
        all_entities = set()
        all_relations = []
        
        if max_docs:
            json_data = json_data[:max_docs]
        
        print(f"Processing {len(json_data)} documents...")
        print("=" * 80)
        
        for idx, item in enumerate(json_data):
            text = item.get('Article Text', '')
            concepts = item.get('Concept', [])
            
            if not text or len(text.strip()) < 5:
                continue
            
            try:
                # Extract entities
                entities = self.entity_extractor(text)
                all_entities.update(entities)
                
                # Add concepts
                #for concept in concepts:
                    #if concept and isinstance(concept, str):
                        #all_entities.add(concept.lower().strip())
                
                # Extract relations
                relations = self.relation_extractor(text, list(all_entities))
                all_relations.extend(relations)
                
                if (idx + 1) % 20 == 0:
                    print(f"  {idx + 1}/{len(json_data)} docs | {len(all_entities)} entities | {len(all_relations)} relations")
                    
            except Exception as e:
                continue
        
        print(f"\n✓ Extraction complete!")
        print(f"  Total entities: {len(all_entities)}")
        print(f"  Total relations: {len(all_relations)}")
        
        # Build graph
        for subj, pred, obj in all_relations:
            self.graph.add_edge(subj, obj, relation=pred)
        
        print(f"  Graph nodes: {len(self.graph.nodes())}")
        print(f"  Graph edges: {len(self.graph.edges())}")
        
        return self.graph
    
    def cluster_entities(self):
        """Semantic clustering with embeddings"""
        nodes = list(self.graph.nodes())
        
        if len(nodes) == 0:
            print("No nodes to cluster!")
            return self.graph
        
        print(f"\n{'='*80}")
        print(f"SEMANTIC CLUSTERING: {len(nodes)} ENTITIES")
        print(f"{'='*80}")
        
        self.entity_clusters = self.entity_clusterer(nodes)
        
        # Map entities
        entity_mapping = {}
        for cluster_label, cluster_entities in self.entity_clusters.items():
            for entity in cluster_entities:
                entity_mapping[entity] = cluster_label
        
        # Rebuild graph
        new_graph = nx.DiGraph()
        for u, v, data in self.graph.edges(data=True):
            new_u = entity_mapping.get(u, u)
            new_v = entity_mapping.get(v, v)
            relation = data.get('relation', 'related_to')
            
            if new_u == new_v:
                continue
            
            if not new_graph.has_edge(new_u, new_v):
                new_graph.add_edge(new_u, new_v, relation=relation)
        
        self.graph = new_graph
        
        print(f"\n✓ Clustering complete!")
        print(f"  Final nodes: {len(self.graph.nodes())}")
        print(f"  Final edges: {len(self.graph.edges())}")
        
        return self.graph
    
    def save_graph(self, filepath: str):
        data = nx.node_link_data(self.graph)
        with open(filepath, 'w') as f:
            json.dump(data, f, indent=2)
        print(f"✓ Saved to {filepath}")
    
    def export_triples(self, filepath: str):
        triples = []
        for u, v, data in self.graph.edges(data=True):
            triples.append({
                'subject': u,
                'predicate': data.get('relation', 'related_to'),
                'object': v
            })
        import pandas as pd
        df = pd.DataFrame(triples)
        df.to_csv(filepath, index=False)
        print(f"✓ Exported to {filepath}")

# Initialize semantic KGGen (threshold 0.75 = balanced)
kg_gen_semantic = KGGenSemantic(similarity_threshold=0.75)
print("\n✓ KGGen with Semantic Clustering (Embeddings + LLM) created!")
# Out:
# Loading sentence transformer model...
# ✓ Model loaded
#
# ✓ KGGen with Semantic Clustering (Embeddings + LLM) created!

# %%
# ============================================================================
# GENERATE KG FOR ALL THE ARTICLES
# ============================================================================

print("\n" + "=" * 80)
print("GENERATING KNOWLEDGE GRAPHS FOR ALL THE ARTICLES")
print("=" * 80)

all_article_kgs = []

total = len(individual_articles)
print(f"\nProcessing {total} articles...\n")

for idx, article in enumerate(individual_articles):
    article_id = article['id']
    text = article['Article Text']
    #concepts = article['Concept']
    
    # Skip empty articles
    if not text or len(text.strip()) < 5:
        all_article_kgs.append({
            'id': article_id,
            'text': text,
            #'concepts': concepts,
            'graph': nx.DiGraph(),
            'entities': [],
            'relations': [],
            'num_nodes': 0,
            'num_edges': 0
        })
        continue
    
    try:
        # Extract entities for THIS article
        entities = entity_extractor(text)
        
        # Add original concepts as entities
        #for concept in concepts:
            #if concept and isinstance(concept, str):
                #entities.append(concept.lower().strip())
        
        entities = list(set(entities))  # Remove duplicates
        
        # Extract relations for THIS article
        if entities:
            relations = relation_extractor(text, entities)
        else:
            relations = []
        
        # Build graph for THIS article
        graph = nx.DiGraph()
        for subj, pred, obj in relations:
            graph.add_edge(subj, obj, relation=pred)
        
        # Store everything for this article
        all_article_kgs.append({
            'id': article_id,
            'text': text,
            #'concepts': concepts,
            'graph': graph,
            'entities': entities,
            'relations': relations,
            'num_nodes': len(graph.nodes()),
            'num_edges': len(graph.edges())
        })
        
        # Progress update
        if (idx + 1) % 50 == 0:
            print(f"✓ Processed {idx + 1}/{total} articles...")
        
    except Exception as e:
        print(f"✗ Article {article_id}: Error - {str(e)}")
        all_article_kgs.append({
            'id': article_id,
            'text': text,
            #'concepts': concepts,
            'graph': nx.DiGraph(),
            'entities': [],
            'relations': [],
            'num_nodes': 0,
            'num_edges': 0
        })

print(f"\n" + "=" * 80)
print("✓ KNOWLEDGE GRAPH GENERATION COMPLETE!")
print("=" * 80)
print(f"Total articles processed: {len(all_article_kgs)}")
print(f"Articles with graphs: {sum(1 for kg in all_article_kgs if kg['num_edges'] > 0)}")
print(f"Articles without graphs: {sum(1 for kg in all_article_kgs if kg['num_edges'] == 0)}")

# Statistics
total_entities = sum(len(kg['entities']) for kg in all_article_kgs)
total_relations = sum(len(kg['relations']) for kg in all_article_kgs)

print(f"\nTotal entities extracted: {total_entities}")
print(f"Total relations extracted: {total_relations}")

with_graphs = [kg for kg in all_article_kgs if kg['num_edges'] > 0]
if with_graphs:
    avg_nodes = sum(kg['num_nodes'] for kg in with_graphs) / len(with_graphs)
    avg_edges = sum(kg['num_edges'] for kg in with_graphs) / len(with_graphs)
    #print(f"\nAverage nodes per KG: {avg_nodes:.2f}")
    #print(f"Average edges per KG: {avg_edges:.2f}")
# Out:
# ================================================================================
# GENERATING KNOWLEDGE GRAPHS FOR ALL THE ARTICLES
# ================================================================================
#
# Processing 1811 articles...
#
# ✓ Processed 50/1811 articles...
# ✓ Processed 100/1811 articles...
# ✓ Processed 150/1811 articles...
# ✓ Processed 200/1811 articles...
# ✓ Processed 250/1811 articles...
# ✓ Processed 300/1811 articles...
# ✓ Processed 350/1811 articles...
# ✓ Processed 400/1811 articles...
# ✓ Processed 450/1811 articles...
# ✓ Processed 500/1811 articles...
# ✓ Processed 550/1811 articles...
# ✓ Processed 600/1811 articles...
# ✓ Processed 650/1811 articles...
# ✓ Processed 700/1811 articles...
# ✓ Processed 750/1811 articles...
# ✓ Processed 800/1811 articles...
# ✓ Processed 850/1811 articles...
# ✓ Processed 900/1811 articles...
# ✓ Processed 950/1811 articles...
# ✓ Processed 1000/1811 articles...
# ✓ Processed 1050/1811 articles...
# ✓ Processed 1100/1811 articles...
# ✓ Processed 1150/1811 articles...
# ✓ Processed 1200/1811 articles...
# ✓ Processed 1250/1811 articles...
# ✓ Processed 1300/1811 articles...
# ✓ Processed 1350/1811 articles...
# ✓ Processed 1400/1811 articles...
# ✓ Processed 1450/1811 articles...
# ✓ Processed 1500/1811 articles...
# ✓ Processed 1550/1811 articles...
# ✓ Processed 1600/1811 articles...
# ✓ Processed 1650/1811 articles...
# ✓ Processed 1700/1811 articles...
# ✓ Processed 1750/1811 articles...
# ✓ Processed 1800/1811 articles...
#
# ================================================================================
# ✓ KNOWLEDGE GRAPH GENERATION COMPLETE!
# ================================================================================
# Total articles processed: 1811
# Articles with graphs: 1650
# Articles without graphs: 161
#
# Total entities extracted: 6083
# Total relations extracted: 4821

# %%
# ============================================================================
# STEP 1: IMPORTS
# ============================================================================

import json
import networkx as nx
from typing import List, Dict, Set, Tuple
import dspy
from dspy.signatures import Signature
from dspy import OutputField, InputField
import pandas as pd
import os
from collections import Counter
import numpy as np

print("✓ All imports successful!")
# Out:
# ✓ All imports successful!

# %%
# ============================================================================
# SAVE KNOWLEDGE GRAPHS TO JSON FILE
# ============================================================================

import json
import networkx as nx

def save_knowledge_graphs(all_article_kgs, filepath='/kaggle/working/article_knowledge_graphs.json'):
    """
    Save knowledge graphs to JSON file.
    
    Args:
        all_article_kgs: List of dictionaries containing KG information
        filepath: Path to save the JSON file
    """
    # Convert NetworkX graphs to serializable format
    serializable_kgs = []
    
    for kg_data in all_article_kgs:
        # Convert NetworkX graph to node-link format
        graph = kg_data['graph']
        graph_dict = nx.node_link_data(graph) if graph.number_of_nodes() > 0 else None
        
        serializable_kg = {
            'id': kg_data['id'],
            'text': kg_data['text'],
            'entities': kg_data['entities'],
            'relations': kg_data['relations'],
            'num_nodes': kg_data['num_nodes'],
            'num_edges': kg_data['num_edges'],
            'graph_data': graph_dict  # Serialized graph
        }
        
        serializable_kgs.append(serializable_kg)
    
    # Save to JSON
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(serializable_kgs, f, indent=2, ensure_ascii=False)
    
    print(f"\n{'='*80}")
    print("KNOWLEDGE GRAPHS SAVED")
    print(f"{'='*80}")
    print(f"Saved {len(serializable_kgs)} knowledge graphs to:")
    print(f"  {filepath}")
    print(f"\nFile size: {len(json.dumps(serializable_kgs)) / (1024*1024):.2f} MB")
    print(f"Articles with graphs: {sum(1 for kg in serializable_kgs if kg['num_edges'] > 0)}")
    print(f"Articles without graphs: {sum(1 for kg in serializable_kgs if kg['num_edges'] == 0)}")

# Save the knowledge graphs
save_knowledge_graphs(all_article_kgs, '/kaggle/working/article_knowledge_graphs.json')

print("\n✓ Knowledge graphs saved successfully!")
print("You can now proceed to the topic classification step.")
# Out:
# ================================================================================
# KNOWLEDGE GRAPHS SAVED
# ================================================================================
# Saved 1811 knowledge graphs to:
#   /kaggle/working/article_knowledge_graphs.json
#
# File size: 1.24 MB
# Articles with graphs: 1650
# Articles without graphs: 161
#
# ✓ Knowledge graphs saved successfully!
# You can now proceed to the topic classification step.

# %%
# ============================================================================
# STEP 3: LOAD DATA AND EXISTING KNOWLEDGE GRAPHS
# ============================================================================

def load_json_data(filepath: str) -> List[Dict]:
    """Load JSON data from file"""
    with open(filepath, 'r', encoding='utf-8') as f:
        data = json.load(f)
    print(f"✓ Loaded {len(data)} documents from {filepath}")
    return data

def load_knowledge_graphs(filepath: str) -> List[Dict]:
    """Load previously created knowledge graphs"""
    if not os.path.exists(filepath):
        print(f"\n⚠️  WARNING: Knowledge graph file not found at {filepath}")
        return None
    
    with open(filepath, 'r', encoding='utf-8') as f:
        kgs = json.load(f)
    print(f"✓ Loaded {len(kgs)} knowledge graphs from {filepath}")
    return kgs

# Load your data
articles = load_json_data('/kaggle/input/zstikg/Mp3 playerData-set.json')
knowledge_graphs = load_knowledge_graphs('/kaggle/working/article_knowledge_graphs.json')

# Only classify articles that have KGs
articles_with_kgs = articles[:len(knowledge_graphs)] 

if knowledge_graphs is None:
    print("\n❌ Cannot proceed without knowledge graphs. Please save them first.")
else:
    print(f"\n✓ Successfully loaded {len(articles)} articles and {len(knowledge_graphs)} KGs")
    print("✓ Ready to proceed with topic classification!")
# Out:
# ✓ Loaded 1811 documents from /kaggle/input/zstikg/Mp3 playerData-set.json
# ✓ Loaded 1811 knowledge graphs from /kaggle/working/article_knowledge_graphs.json
#
# ✓ Successfully loaded 1811 articles and 1811 KGs
# ✓ Ready to proceed with topic classification!

# %%
# ============================================================================
# STEP 4: EXTRACT ALL UNIQUE CONCEPTS FROM DATASET
# ============================================================================

def extract_unique_concepts(articles: List[Dict]) -> List[str]:
    """
    Extract all unique concepts from the dataset's 'Concept' field.
    
    Args:
        articles: List of article dictionaries
    
    Returns:
        Sorted list of unique concepts
    """
    all_concepts = set()
    
    for article in articles:
        # Get concepts from the Concept field
        if 'Concept' in article and article['Concept']:
            if isinstance(article['Concept'], list):
                all_concepts.update([c.lower().strip() for c in article['Concept'] if c])
            elif isinstance(article['Concept'], str):
                all_concepts.add(article['Concept'].lower().strip())
    
    # Convert to sorted list
    unique_concepts = sorted(list(all_concepts))
    
    print(f"\n{'='*80}")
    print(f"UNIQUE CONCEPTS EXTRACTED FROM DATASET")
    print(f"{'='*80}")
    print(f"Total unique concepts: {len(unique_concepts)}")
    print(f"\nFirst 20 concepts: {unique_concepts[:20]}")
    print(f"\nLast 20 concepts: {unique_concepts[-20:]}")
    
    return unique_concepts


# Extract all unique concepts from the dataset
all_concepts = extract_unique_concepts(articles)

# Save concept list for reference
with open('/kaggle/working/all_concepts.json', 'w') as f:
    json.dump(all_concepts, f, indent=2)

print(f"\n✓ Saved concept list to /kaggle/working/all_concepts.json")
# Out:
# ================================================================================
# UNIQUE CONCEPTS EXTRACTED FROM DATASET
# ================================================================================
# Total unique concepts: 20
#
# First 20 concepts: ['battery', 'button', 'design', 'eax', 'hardware', 'manual', 'navigation', 'player', 'playlist', 'price', 'screen', 'search', 'size', 'software', 'sound', 'storage', 'transfer', 'use', 'warranty', 'weight']
#
# Last 20 concepts: ['battery', 'button', 'design', 'eax', 'hardware', 'manual', 'navigation', 'player', 'playlist', 'price', 'screen', 'search', 'size', 'software', 'sound', 'storage', 'transfer', 'use', 'warranty', 'weight']
#
# ✓ Saved concept list to /kaggle/working/all_concepts.json

# %%
# ============================================================================
# STEP 5: KG FORMATTING FUNCTION
# ============================================================================

def format_kg_for_llm(kg_data: Dict) -> str:
    """Format knowledge graph into readable text for the LLM."""
    if not kg_data or kg_data.get('num_edges', 0) == 0:
        return "No knowledge graph available."
    
    # Format entities
    entities = kg_data.get('entities', [])
    entities_str = ", ".join(entities[:30]) if entities else "None"
    if len(entities) > 30:
        entities_str += f"... ({len(entities) - 30} more)"
    
    # Format relationships
    relations = kg_data.get('relations', [])
    if relations:
        relationships = []
        for relation in relations[:20]:
            if isinstance(relation, (list, tuple)) and len(relation) >= 3:
                source, rel_type, target = relation[0], relation[1], relation[2]
                relationships.append(f"{source} --[{rel_type}]--> {target}")
        relationships_str = "\n".join(relationships)
        if len(relations) > 20:
            relationships_str += f"\n... ({len(relations) - 20} more relationships)"
    else:
        relationships_str = "None"
    
    kg_summary = f"""Knowledge Graph Summary:
Entities: {entities_str}

Key Relationships:
{relationships_str}"""
    
    return kg_summary

print("✓ KG formatting function ready")
# Out:
# ✓ KG formatting function ready

# %%
# ============================================================================
# STEP 6: DEFINE DSPY SIGNATURE FOR TOPIC CLASSIFICATION
# ============================================================================

class TopicClassification(Signature):
    """Given an article text, its knowledge graph, and a list of possible topics,
    determine which topics (can be multiple) are most relevant to this article.
    Return only topic names that are actually present in the available_topics list."""
    
    article_text: str = InputField(
        desc="The text content of the article"
    )
    knowledge_graph: str = InputField(
        desc="Knowledge graph extracted from the article showing entities and relationships"
    )
    available_topics: str = InputField(
        desc="Comma-separated list of all possible topic/concept names"
    )
    
    predicted_topics: str = OutputField(
        desc="Comma-separated list of relevant topics from the available_topics list. "
             "Only return topics that actually appear in the available_topics list. "
             "If multiple topics apply, list them all (maximum 5). If no topics match well, return 'none'."
    )
    #confidence: str = OutputField(
        #desc="Confidence level: high, medium, or low"
    #)
    #reasoning: str = OutputField(
        #desc="Brief explanation of why these topics were chosen based on the article and knowledge graph"
    #)

print("✓ Topic classification signature defined")
# Out:
# ✓ Topic classification signature defined

# %%
# ============================================================================
# STEP 7: CREATE TOPIC CLASSIFIER CLASS
# ============================================================================

class ArticleTopicClassifier:
    """Multi-label topic classifier using article text, KG, and available topics."""
    
    def __init__(self, available_topics: List[str]):
        self.available_topics = available_topics
        self.available_topics_str = ", ".join(available_topics)
        self.classifier = dspy.ChainOfThought(TopicClassification)
        print(f"✓ Classifier initialized with {len(available_topics)} possible topics")
    
    def classify_article(self, article_text: str, kg_data: Dict) -> Dict:
        """Classify a single article."""
        kg_summary = format_kg_for_llm(kg_data)
        
        # Truncate article if too long
        #max_text_length = 500
        #if len(article_text) > max_text_length:
            #article_text = article_text[:max_text_length] + "..."
        
        try:
            result = self.classifier(
                article_text=article_text,
                knowledge_graph=kg_summary,
                available_topics=self.available_topics_str
            )
            
            predicted_topics_raw = result.predicted_topics
            
            if predicted_topics_raw.lower() == 'none':
                predicted_topics = []
            else:
                predicted_topics = [
                    t.strip().lower() 
                    for t in predicted_topics_raw.split(',')
                    if t.strip()
                ]
                predicted_topics = [
                    t for t in predicted_topics 
                    if t in [at.lower() for at in self.available_topics]
                ]
            
            return {
                'predicted_topics': predicted_topics,
                'num_topics': len(predicted_topics),
                #'confidence': result.confidence,
                #'reasoning': result.reasoning
            }
            
        except Exception as e:
            print(f"  Error: {str(e)}")
            return {
                'predicted_topics': [],
                'num_topics': 0,
                #'confidence': 'error',
                #'reasoning': f'Classification failed: {str(e)}'
            }
    
    def classify_dataset(self, articles: List[Dict], knowledge_graphs: List[Dict],
                        max_articles: int = None) -> List[Dict]:
        """Classify multiple articles."""
        results = []
        kg_dict = {kg['id']: kg for kg in knowledge_graphs}
        
        if max_articles:
            articles = articles[:max_articles]
        
        print(f"\n{'='*80}")
        print(f"CLASSIFYING {len(articles)} ARTICLES")
        print(f"{'='*80}\n")
        
        for idx, article in enumerate(articles):
            print(f"Processing article {idx}...", end=" ")
            
            article_text = article.get('Article Text', '')
            kg_data = kg_dict.get(idx, {'num_edges': 0})
            classification = self.classify_article(article_text, kg_data)
            
            result = {
                'article_id': idx,
                'article_text': article_text + "...",
                'true_concepts': article.get('Concept', []),
                'predicted_topics': classification['predicted_topics'],
                'num_predicted': classification['num_topics'],
                #'confidence': classification['confidence'],
                #'reasoning': classification['reasoning']
            }
            
            results.append(result)
            print(f"✓ Found {len(classification['predicted_topics'])} topics")
        
        return results

print("✓ Classifier class defined")
# Out:
# ✓ Classifier class defined

# %%
# ============================================================================
# STEP 8: ANALYSIS FUNCTIONS
# ============================================================================

def analyze_classification_results(results: List[Dict], available_topics: List[str]) -> Dict:
    """Analyze classification results and generate statistics."""
    from collections import Counter
    
    topic_counts = Counter()
    #confidence_dist = Counter()
    
    multi_label_count = 0
    no_label_count = 0
    
    for result in results:
        predicted = result['predicted_topics']
        
        if len(predicted) == 0:
            no_label_count += 1
        elif len(predicted) > 1:
            multi_label_count += 1
        
        for topic in predicted:
            topic_counts[topic] += 1
        
        #confidence_dist[result['confidence']] += 1
    
    stats = {
        'total_articles': len(results),
        'articles_with_topics': len(results) - no_label_count,
        'articles_without_topics': no_label_count,
        'multi_label_articles': multi_label_count,
        #'avg_topics_per_article': sum(len(r['predicted_topics']) for r in results) / len(results),
        #'most_common_topics': topic_counts.most_common(10)
    }
    
    print(f"\n{'='*80}")
    print("CLASSIFICATION RESULTS SUMMARY")
    print(f"{'='*80}")
    print(f"\nTotal articles: {stats['total_articles']}")
    print(f"Articles with topics: {stats['articles_with_topics']} ({stats['articles_with_topics']/stats['total_articles']*100:.1f}%)")
    print(f"Multi-label articles: {stats['multi_label_articles']} ({stats['multi_label_articles']/stats['total_articles']*100:.1f}%)")
    #print(f"Average topics per article: {stats['avg_topics_per_article']:.2f}")
    
    print(f"\n{'='*80}")
    print("TOP 10 MOST FREQUENT TOPICS")
    print(f"{'='*80}")
    #for topic, count in stats['most_common_topics']:
        #print(f"  {topic}: {count} articles ({count/stats['total_articles']*100:.1f}%)")
    
    return stats

def save_results(results: List[Dict], output_path: str):
    """Save classification results to JSON file."""
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(results, f, indent=2, ensure_ascii=False)
    print(f"\n✓ Results saved to {output_path}")

def export_to_csv(results: List[Dict], output_path: str):
    """Export results to CSV for easy analysis."""
    rows = []
    for r in results:
        rows.append({
            'article_id': r['article_id'],
            #'article_preview': r['article_text'],
            'true_concepts': '|'.join(r['true_concepts']) if r['true_concepts'] else '',
            'predicted_topics': '|'.join(r['predicted_topics']),
            'num_predicted': len(r['predicted_topics']),
            #'confidence': r['confidence'],
            #'reasoning': r['reasoning']
        })
    
    df = pd.DataFrame(rows)
    df.to_csv(output_path, index=False, encoding='utf-8')
    print(f"✓ CSV exported to {output_path}")

print("✓ Analysis functions defined")
# Out:
# ✓ Analysis functions defined

# %%
# ============================================================================
# RUN CLASSIFICATION ON ALL THE ARTICLES
# ============================================================================

# Initialize classifier
classifier = ArticleTopicClassifier(all_concepts)

# Classify all the articles with KGs
results = classifier.classify_dataset(
    articles=articles,
    knowledge_graphs=knowledge_graphs,
    max_articles=10000
)

# Analyze results
stats = analyze_classification_results(results, all_concepts)

# Save results
save_results(results, '/kaggle/working/topic_classification_results.json')
export_to_csv(results, '/kaggle/working/topic_classification_results.csv')

# Show sample results
print(f"\n{'='*80}")
print("SAMPLE RESULTS (First 3)")
print(f"{'='*80}\n")

for result in results[:3]:
    print(f"Article {result['article_id']}:")
    print(f"  Preview: {result['article_text']}")
    print(f"  True: {result['true_concepts']}")
    print(f"  Predicted: {result['predicted_topics']}")
    #print(f"  Confidence: {result['confidence']}")
    print()
# Out:
# ✓ Classifier initialized with 20 possible topics
#
# ================================================================================
# CLASSIFYING 1811 ARTICLES
# ================================================================================
#
# Processing article 0... ✓ Found 3 topics
# Processing article 1... ✓ Found 5 topics
# Processing article 2... ✓ Found 4 topics
# Processing article 3... ✓ Found 1 topics
# Processing article 4... ✓ Found 5 topics
# Processing article 5... ✓ Found 3 topics
# Processing article 6... ✓ Found 1 topics
# Processing article 7... ✓ Found 3 topics
# Processing article 8... ✓ Found 5 topics
# Processing article 9... ✓ Found 2 topics
# Processing article 10... ✓ Found 3 topics
# Processing article 11... ✓ Found 3 topics
# Processing article 12... ✓ Found 1 topics
# Processing article 13... ✓ Found 1 topics
# Processing article 14... ✓ Found 5 topics
# Processing article 15... ✓ Found 5 topics
# Processing article 16... ✓ Found 3 topics
# Processing article 17... ✓ Found 3 topics
# Processing article 18... ✓ Found 4 topics
# Processing article 19... ✓ Found 1 topics
# Processing article 20... ✓ Found 4 topics
# Processing article 21... ✓ Found 2 topics
# Processing article 22... ✓ Found 3 topics
# Processing article 23... ✓ Found 5 topics
# Processing article 24... ✓ Found 0 topics
# Processing article 25... ✓ Found 2 topics
# Processing article 26... ✓ Found 1 topics
# Processing article 27... ✓ Found 1 topics
# Processing article 28... ✓ Found 3 topics
# Processing article 29... ✓ Found 2 topics
# Processing article 30... ✓ Found 4 topics
# Processing article 31... ✓ Found 4 topics
# Processing article 32... ✓ Found 5 topics
# Processing article 33... ✓ Found 1 topics
# Processing article 34... ✓ Found 3 topics
# Processing article 35... ✓ Found 3 topics
# Processing article 36... ✓ Found 5 topics
# Processing article 37... ✓ Found 2 topics
# Processing article 38... ✓ Found 5 topics
# Processing article 39... ✓ Found 3 topics
# Processing article 40... ✓ Found 3 topics
# Processing article 41... ✓ Found 1 topics
# Processing article 42... ✓ Found 1 topics
# Processing article 43... ✓ Found 3 topics
# Processing article 44... ✓ Found 1 topics
# Processing article 45... ✓ Found 2 topics
# Processing article 46... ✓ Found 2 topics
# Processing article 47... ✓ Found 1 topics
# Processing article 48... ✓ Found 1 topics
# Processing article 49... ✓ Found 5 topics
# Processing article 50... ✓ Found 4 topics
# Processing article 51... ✓ Found 3 topics
# Processing article 52... ✓ Found 5 topics
# Processing article 53... ✓ Found 5 topics
# Processing article 54... ✓ Found 1 topics
# Processing article 55... ✓ Found 4 topics
# Processing article 56... ✓ Found 2 topics
# Processing article 57... ✓ Found 5 topics
# Processing article 58... ✓ Found 2 topics
# Processing article 59... ✓ Found 1 topics
# Processing article 60... ✓ Found 1 topics
# Processing article 61... ✓ Found 1 topics
# Processing article 62... ✓ Found 2 topics
# Processing article 63... ✓ Found 1 topics
# Processing article 64... ✓ Found 1 topics
# Processing article 65... ✓ Found 1 topics
# Processing article 66... ✓ Found 1 topics
# Processing article 67... ✓ Found 3 topics
# Processing article 68... ✓ Found 4 topics
# Processing article 69... ✓ Found 1 topics
# Processing article 70... ✓ Found 5 topics
# Processing article 71... ✓ Found 2 topics
# Processing article 72... ✓ Found 3 topics
# Processing article 73... ✓ Found 4 topics
# Processing article 74... ✓ Found 1 topics
# Processing article 75... ✓ Found 2 topics
# Processing article 76... ✓ Found 3 topics
# Processing article 77... ✓ Found 1 topics
# Processing article 78... ✓ Found 4 topics
# Processing article 79... ✓ Found 1 topics
# Processing article 80... ✓ Found 1 topics
# Processing article 81... ✓ Found 1 topics
# Processing article 82... ✓ Found 3 topics
# Processing article 83... ✓ Found 4 topics
# Processing article 84... ✓ Found 2 topics
# Processing article 85... ✓ Found 2 topics
# Processing article 86... ✓ Found 1 topics
# Processing article 87... ✓ Found 2 topics
# Processing article 88... ✓ Found 1 topics
# Processing article 89... ✓ Found 3 topics
# Processing article 90... ✓ Found 1 topics
# Processing article 91... ✓ Found 1 topics
# Processing article 92... ✓ Found 1 topics
# Processing article 93... ✓ Found 1 topics
# Processing article 94... ✓ Found 2 topics
# Processing article 95... ✓ Found 1 topics
# Processing article 96... ✓ Found 2 topics
# Processing article 97... ✓ Found 2 topics
# Processing article 98... ✓ Found 3 topics
# Processing article 99... ✓ Found 1 topics
# Processing article 100... ✓ Found 4 topics
# Processing article 101... ✓ Found 1 topics
# Processing article 102... ✓ Found 1 topics
# Processing article 103... ✓ Found 1 topics
# Processing article 104... ✓ Found 2 topics
# Processing article 105... ✓ Found 3 topics
# Processing article 106... ✓ Found 2 topics
# Processing article 107... ✓ Found 1 topics
# Processing article 108... ✓ Found 3 topics
# Processing article 109... ✓ Found 2 topics
# Processing article 110... ✓ Found 1 topics
# Processing article 111... ✓ Found 3 topics
# Processing article 112... ✓ Found 4 topics
# Processing article 113... ✓ Found 2 topics
# Processing article 114... ✓ Found 2 topics
# Processing article 115... ✓ Found 4 topics
# Processing article 116... ✓ Found 1 topics
# Processing article 117... ✓ Found 1 topics
# Processing article 118... ✓ Found 1 topics
# Processing article 119... ✓ Found 1 topics
# Processing article 120... ✓ Found 3 topics
# Processing article 121... ✓ Found 2 topics
# Processing article 122... ✓ Found 5 topics
# Processing article 123... ✓ Found 2 topics
# Processing article 124... ✓ Found 2 topics
# Processing article 125... ✓ Found 2 topics
# Processing article 126... ✓ Found 4 topics
# Processing article 127... ✓ Found 0 topics
# Processing article 128... ✓ Found 2 topics
# Processing article 129... ✓ Found 3 topics
# Processing article 130... ✓ Found 5 topics
# Processing article 131... ✓ Found 3 topics
# Processing article 132... ✓ Found 3 topics
# Processing article 133... ✓ Found 2 topics
# Processing article 134... ✓ Found 2 topics
# Processing article 135... ✓ Found 1 topics
# Processing article 136... ✓ Found 3 topics
# Processing article 137... ✓ Found 2 topics
# Processing article 138... ✓ Found 2 topics
# Processing article 139... ✓ Found 4 topics
# Processing article 140... ✓ Found 3 topics
# Processing article 141... ✓ Found 2 topics
# Processing article 142... ✓ Found 2 topics
# Processing article 143... ✓ Found 3 topics
# Processing article 144... ✓ Found 3 topics
# Processing article 145... ✓ Found 2 topics
# Processing article 146... ✓ Found 3 topics
# Processing article 147... ✓ Found 2 topics
# Processing article 148... ✓ Found 3 topics
# Processing article 149... ✓ Found 2 topics
# Processing article 150... ✓ Found 4 topics
# Processing article 151... ✓ Found 3 topics
# Processing article 152... ✓ Found 4 topics
# Processing article 153... ✓ Found 0 topics
# Processing article 154... ✓ Found 3 topics
# Processing article 155... ✓ Found 3 topics
# Processing article 156... ✓ Found 3 topics
# Processing article 157... ✓ Found 1 topics
# Processing article 158... ✓ Found 2 topics
# Processing article 159... ✓ Found 0 topics
# Processing article 160... ✓ Found 3 topics
# Processing article 161... ✓ Found 5 topics
# Processing article 162... ✓ Found 2 topics
# Processing article 163... ✓ Found 3 topics
# Processing article 164... ✓ Found 0 topics
# Processing article 165... ✓ Found 0 topics
# Processing article 166... ✓ Found 5 topics
# Processing article 167... ✓ Found 2 topics
# Processing article 168... ✓ Found 3 topics
# Processing article 169... ✓ Found 2 topics
# Processing article 170... ✓ Found 2 topics
# Processing article 171... ✓ Found 1 topics
# Processing article 172... ✓ Found 1 topics
# Processing article 173... ✓ Found 2 topics
# Processing article 174... ✓ Found 3 topics
# Processing article 175... ✓ Found 1 topics
# Processing article 176... ✓ Found 0 topics
# Processing article 177... ✓ Found 2 topics
# Processing article 178... ✓ Found 1 topics
# Processing article 179... ✓ Found 2 topics
# Processing article 180... ✓ Found 1 topics
# Processing article 181... ✓ Found 3 topics
# Processing article 182... ✓ Found 1 topics
# Processing article 183... ✓ Found 4 topics
# Processing article 184... ✓ Found 1 topics
# Processing article 185... ✓ Found 3 topics
# Processing article 186... ✓ Found 3 topics
# Processing article 187... ✓ Found 2 topics
# Processing article 188... ✓ Found 3 topics
# Processing article 189... ✓ Found 2 topics
# Processing article 190... ✓ Found 1 topics
# Processing article 191... ✓ Found 2 topics
# Processing article 192... ✓ Found 1 topics
# Processing article 193... ✓ Found 4 topics
# Processing article 194... ✓ Found 0 topics
# Processing article 195... ✓ Found 2 topics
# Processing article 196... ✓ Found 2 topics
# Processing article 197... ✓ Found 3 topics
# Processing article 198... ✓ Found 2 topics
# Processing article 199... ✓ Found 5 topics
# Processing article 200... ✓ Found 1 topics
# Processing article 201... ✓ Found 3 topics
# Processing article 202... ✓ Found 2 topics
# Processing article 203... ✓ Found 0 topics
# Processing article 204... ✓ Found 2 topics
# Processing article 205... ✓ Found 1 topics
# Processing article 206... ✓ Found 1 topics
# Processing article 207... ✓ Found 4 topics
# Processing article 208... ✓ Found 2 topics
# Processing article 209... ✓ Found 1 topics
# Processing article 210... ✓ Found 3 topics
# Processing article 211... ✓ Found 3 topics
# Processing article 212... ✓ Found 3 topics
# Processing article 213... ✓ Found 5 topics
# Processing article 214... ✓ Found 4 topics
# Processing article 215... ✓ Found 3 topics
# Processing article 216... ✓ Found 1 topics
# Processing article 217... ✓ Found 1 topics
# Processing article 218... ✓ Found 0 topics
# Processing article 219... ✓ Found 1 topics
# Processing article 220... ✓ Found 1 topics
# Processing article 221... ✓ Found 3 topics
# Processing article 222... ✓ Found 1 topics
# Processing article 223... ✓ Found 3 topics
# Processing article 224... ✓ Found 1 topics
# Processing article 225... ✓ Found 0 topics
# Processing article 226... ✓ Found 2 topics
# Processing article 227... ✓ Found 1 topics
# Processing article 228... ✓ Found 1 topics
# Processing article 229... ✓ Found 3 topics
# Processing article 230... ✓ Found 1 topics
# Processing article 231... ✓ Found 2 topics
# Processing article 232... ✓ Found 3 topics
# Processing article 233... ✓ Found 1 topics
# Processing article 234... ✓ Found 2 topics
# Processing article 235... ✓ Found 1 topics
# Processing article 236... ✓ Found 2 topics
# Processing article 237... ✓ Found 3 topics
# Processing article 238... ✓ Found 2 topics
# Processing article 239... ✓ Found 4 topics
# Processing article 240... ✓ Found 5 topics
# Processing article 241... ✓ Found 3 topics
# Processing article 242... ✓ Found 5 topics
# Processing article 243... ✓ Found 1 topics
# Processing article 244... ✓ Found 3 topics
# Processing article 245... ✓ Found 4 topics
# Processing article 246... ✓ Found 1 topics
# Processing article 247... ✓ Found 1 topics
# Processing article 248... ✓ Found 1 topics
# Processing article 249... ✓ Found 5 topics
# Processing article 250... ✓ Found 5 topics
# Processing article 251... ✓ Found 5 topics
# Processing article 252... ✓ Found 2 topics
# Processing article 253... ✓ Found 5 topics
# Processing article 254... ✓ Found 1 topics
# Processing article 255... ✓ Found 4 topics
# Processing article 256... ✓ Found 2 topics
# Processing article 257... ✓ Found 2 topics
# Processing article 258... ✓ Found 3 topics
# Processing article 259... ✓ Found 1 topics
# Processing article 260... ✓ Found 4 topics
# Processing article 261... ✓ Found 4 topics
# Processing article 262... ✓ Found 4 topics
# Processing article 263... ✓ Found 0 topics
# Processing article 264... ✓ Found 2 topics
# Processing article 265... ✓ Found 5 topics
# Processing article 266... ✓ Found 1 topics
# Processing article 267... ✓ Found 4 topics
# Processing article 268... ✓ Found 0 topics
# Processing article 269... ✓ Found 1 topics
# Processing article 270... ✓ Found 5 topics
# Processing article 271... ✓ Found 1 topics
# Processing article 272... ✓ Found 2 topics
# Processing article 273... ✓ Found 2 topics
# Processing article 274... ✓ Found 0 topics
# Processing article 275... ✓ Found 1 topics
# Processing article 276... ✓ Found 2 topics
# Processing article 277... ✓ Found 5 topics
# Processing article 278... ✓ Found 2 topics
# Processing article 279... ✓ Found 5 topics
# Processing article 280... ✓ Found 2 topics
# Processing article 281... ✓ Found 2 topics
# Processing article 282... ✓ Found 5 topics
# Processing article 283... ✓ Found 1 topics
# Processing article 284... ✓ Found 2 topics
# Processing article 285... ✓ Found 5 topics
# Processing article 286... ✓ Found 2 topics
# Processing article 287... ✓ Found 2 topics
# Processing article 288... ✓ Found 3 topics
# Processing article 289... ✓ Found 4 topics
# Processing article 290... ✓ Found 3 topics
# Processing article 291... ✓ Found 3 topics
# Processing article 292... ✓ Found 3 topics
# Processing article 293... ✓ Found 2 topics
# Processing article 294... ✓ Found 2 topics
# Processing article 295... ✓ Found 2 topics
# Processing article 296... ✓ Found 5 topics
# Processing article 297... ✓ Found 0 topics
# Processing article 298... ✓ Found 4 topics
# Processing article 299... ✓ Found 1 topics
# Processing article 300... ✓ Found 2 topics
# Processing article 301... ✓ Found 2 topics
# Processing article 302... ✓ Found 1 topics
# Processing article 303... ✓ Found 5 topics
# Processing article 304... ✓ Found 1 topics
# Processing article 305... ✓ Found 2 topics
# Processing article 306... ✓ Found 1 topics
# Processing article 307... ✓ Found 1 topics
# Processing article 308... ✓ Found 5 topics
# Processing article 309... ✓ Found 5 topics
# Processing article 310... ✓ Found 4 topics
# Processing article 311... ✓ Found 4 topics
# Processing article 312... ✓ Found 0 topics
# Processing article 313... ✓ Found 0 topics
# Processing article 314... ✓ Found 2 topics
# Processing article 315... ✓ Found 1 topics
# Processing article 316... ✓ Found 3 topics
# Processing article 317... ✓ Found 1 topics
# Processing article 318... ✓ Found 5 topics
# Processing article 319... ✓ Found 4 topics
# Processing article 320... ✓ Found 2 topics
# Processing article 321... ✓ Found 2 topics
# Processing article 322... ✓ Found 2 topics
# Processing article 323... ✓ Found 2 topics
# Processing article 324... ✓ Found 1 topics
# Processing article 325... ✓ Found 2 topics
# Processing article 326... ✓ Found 2 topics
# Processing article 327... ✓ Found 4 topics
# Processing article 328... ✓ Found 2 topics
# Processing article 329... ✓ Found 3 topics
# Processing article 330... ✓ Found 4 topics
# Processing article 331... ✓ Found 4 topics
# Processing article 332... ✓ Found 1 topics
# Processing article 333... ✓ Found 2 topics
# Processing article 334... ✓ Found 2 topics
# Processing article 335... ✓ Found 2 topics
# Processing article 336... ✓ Found 1 topics
# Processing article 337... ✓ Found 3 topics
# Processing article 338... ✓ Found 5 topics
# Processing article 339... ✓ Found 4 topics
# Processing article 340... ✓ Found 1 topics
# Processing article 341... ✓ Found 2 topics
# Processing article 342... ✓ Found 2 topics
# Processing article 343... ✓ Found 2 topics
# Processing article 344... ✓ Found 4 topics
# Processing article 345... ✓ Found 1 topics
# Processing article 346... ✓ Found 3 topics
# Processing article 347... ✓ Found 2 topics
# Processing article 348... ✓ Found 3 topics
# Processing article 349... ✓ Found 2 topics
# Processing article 350... ✓ Found 1 topics
# Processing article 351... ✓ Found 1 topics
# Processing article 352... ✓ Found 1 topics
# Processing article 353... ✓ Found 5 topics
# Processing article 354... ✓ Found 0 topics
# Processing article 355... ✓ Found 1 topics
# Processing article 356... ✓ Found 4 topics
# Processing article 357... ✓ Found 1 topics
# Processing article 358... ✓ Found 3 topics
# Processing article 359... ✓ Found 3 topics
# Processing article 360... ✓ Found 1 topics
# Processing article 361... ✓ Found 1 topics
# Processing article 362... ✓ Found 2 topics
# Processing article 363... ✓ Found 0 topics
# Processing article 364... ✓ Found 2 topics
# Processing article 365... ✓ Found 2 topics
# Processing article 366... ✓ Found 1 topics
# Processing article 367... ✓ Found 1 topics
# Processing article 368... ✓ Found 2 topics
# Processing article 369... ✓ Found 1 topics
# Processing article 370... ✓ Found 2 topics
# Processing article 371... ✓ Found 2 topics
# Processing article 372... ✓ Found 3 topics
# Processing article 373... ✓ Found 2 topics
# Processing article 374... ✓ Found 0 topics
# Processing article 375... ✓ Found 2 topics
# Processing article 376... ✓ Found 2 topics
# Processing article 377... ✓ Found 2 topics
# Processing article 378... ✓ Found 1 topics
# Processing article 379... ✓ Found 5 topics
# Processing article 380... ✓ Found 2 topics
# Processing article 381... ✓ Found 4 topics
# Processing article 382... ✓ Found 1 topics
# Processing article 383... ✓ Found 5 topics
# Processing article 384... ✓ Found 3 topics
# Processing article 385... ✓ Found 5 topics
# Processing article 386... ✓ Found 1 topics
# Processing article 387... ✓ Found 1 topics
# Processing article 388... ✓ Found 1 topics
# Processing article 389... ✓ Found 1 topics
# Processing article 390... ✓ Found 2 topics
# Processing article 391... ✓ Found 4 topics
# Processing article 392... ✓ Found 4 topics
# Processing article 393... ✓ Found 0 topics
# Processing article 394... ✓ Found 5 topics
# Processing article 395... ✓ Found 3 topics
# Processing article 396... ✓ Found 1 topics
# Processing article 397... ✓ Found 1 topics
# Processing article 398... ✓ Found 5 topics
# Processing article 399... ✓ Found 2 topics
# Processing article 400... ✓ Found 3 topics
# Processing article 401... ✓ Found 2 topics
# Processing article 402... ✓ Found 1 topics
# Processing article 403... ✓ Found 2 topics
# Processing article 404... ✓ Found 1 topics
# Processing article 405... ✓ Found 1 topics
# Processing article 406... ✓ Found 1 topics
# Processing article 407... ✓ Found 1 topics
# Processing article 408... ✓ Found 2 topics
# Processing article 409... ✓ Found 1 topics
# Processing article 410... ✓ Found 0 topics
# Processing article 411... ✓ Found 2 topics
# Processing article 412... ✓ Found 1 topics
# Processing article 413... ✓ Found 1 topics
# Processing article 414... ✓ Found 4 topics
# Processing article 415... ✓ Found 5 topics
# Processing article 416... ✓ Found 2 topics
# Processing article 417... ✓ Found 3 topics
# Processing article 418... ✓ Found 0 topics
# Processing article 419... ✓ Found 1 topics
# Processing article 420... ✓ Found 2 topics
# Processing article 421... ✓ Found 1 topics
# Processing article 422... ✓ Found 0 topics
# Processing article 423... ✓ Found 3 topics
# Processing article 424... ✓ Found 1 topics
# Processing article 425... ✓ Found 2 topics
# Processing article 426... ✓ Found 5 topics
# Processing article 427... ✓ Found 1 topics
# Processing article 428... ✓ Found 5 topics
# Processing article 429... ✓ Found 1 topics
# Processing article 430... ✓ Found 2 topics
# Processing article 431... ✓ Found 2 topics
# Processing article 432... ✓ Found 5 topics
# Processing article 433... ✓ Found 2 topics
# Processing article 434... ✓ Found 3 topics
# Processing article 435... ✓ Found 4 topics
# Processing article 436... ✓ Found 2 topics
# Processing article 437... ✓ Found 5 topics
# Processing article 438... ✓ Found 3 topics
# Processing article 439... ✓ Found 3 topics
# Processing article 440... ✓ Found 0 topics
# Processing article 441... ✓ Found 4 topics
# Processing article 442... ✓ Found 3 topics
# Processing article 443... ✓ Found 1 topics
# Processing article 444... ✓ Found 2 topics
# Processing article 445... ✓ Found 3 topics
# Processing article 446... ✓ Found 4 topics
# Processing article 447... ✓ Found 3 topics
# Processing article 448... ✓ Found 2 topics
# Processing article 449... ✓ Found 3 topics
# Processing article 450... ✓ Found 4 topics
# Processing article 451... ✓ Found 1 topics
# Processing article 452... ✓ Found 2 topics
# Processing article 453... ✓ Found 2 topics
# Processing article 454... ✓ Found 5 topics
# Processing article 455... ✓ Found 0 topics
# Processing article 456... ✓ Found 2 topics
# Processing article 457... ✓ Found 4 topics
# Processing article 458... ✓ Found 1 topics
# Processing article 459... ✓ Found 1 topics
# Processing article 460... ✓ Found 5 topics
# Processing article 461... ✓ Found 5 topics
# Processing article 462... ✓ Found 5 topics
# Processing article 463... ✓ Found 3 topics
# Processing article 464... ✓ Found 5 topics
# Processing article 465... ✓ Found 2 topics
# Processing article 466... ✓ Found 1 topics
# Processing article 467... ✓ Found 3 topics
# Processing article 468... ✓ Found 5 topics
# Processing article 469... ✓ Found 3 topics
# Processing article 470... ✓ Found 2 topics
# Processing article 471... ✓ Found 3 topics
# Processing article 472... ✓ Found 5 topics
# Processing article 473... ✓ Found 2 topics
# Processing article 474... ✓ Found 1 topics
# Processing article 475... ✓ Found 2 topics
# Processing article 476... ✓ Found 3 topics
# Processing article 477... ✓ Found 2 topics
# Processing article 478... ✓ Found 3 topics
# Processing article 479... ✓ Found 3 topics
# Processing article 480... ✓ Found 4 topics
# Processing article 481... ✓ Found 1 topics
# Processing article 482... ✓ Found 4 topics
# Processing article 483... ✓ Found 2 topics
# Processing article 484... ✓ Found 2 topics
# Processing article 485... ✓ Found 2 topics
# Processing article 486... ✓ Found 4 topics
# Processing article 487... ✓ Found 1 topics
# Processing article 488... ✓ Found 1 topics
# Processing article 489... ✓ Found 2 topics
# Processing article 490... ✓ Found 1 topics
# Processing article 491... ✓ Found 4 topics
# Processing article 492... ✓ Found 2 topics
# Processing article 493... ✓ Found 1 topics
# Processing article 494... ✓ Found 1 topics
# Processing article 495... ✓ Found 2 topics
# Processing article 496... ✓ Found 1 topics
# Processing article 497... ✓ Found 4 topics
# Processing article 498... ✓ Found 3 topics
# Processing article 499... ✓ Found 0 topics
# Processing article 500... ✓ Found 1 topics
# Processing article 501... ✓ Found 2 topics
# Processing article 502... ✓ Found 1 topics
# Processing article 503... ✓ Found 2 topics
# Processing article 504... ✓ Found 1 topics
# Processing article 505... ✓ Found 1 topics
# Processing article 506... ✓ Found 4 topics
# Processing article 507... ✓ Found 21 topics
# Processing article 508... ✓ Found 0 topics
# Processing article 509... ✓ Found 2 topics
# Processing article 510... ✓ Found 3 topics
# Processing article 511... ✓ Found 1 topics
# Processing article 512... ✓ Found 5 topics
# Processing article 513... ✓ Found 3 topics
# Processing article 514... ✓ Found 2 topics
# Processing article 515... ✓ Found 1 topics
# Processing article 516... ✓ Found 1 topics
# Processing article 517... ✓ Found 1 topics
# Processing article 518... ✓ Found 2 topics
# Processing article 519... ✓ Found 4 topics
# Processing article 520... ✓ Found 2 topics
# Processing article 521... ✓ Found 1 topics
# Processing article 522... ✓ Found 2 topics
# Processing article 523... ✓ Found 1 topics
# Processing article 524... ✓ Found 2 topics
# Processing article 525... ✓ Found 4 topics
# Processing article 526... ✓ Found 5 topics
# Processing article 527... ✓ Found 2 topics
# Processing article 528... ✓ Found 4 topics
# Processing article 529... ✓ Found 1 topics
# Processing article 530... ✓ Found 2 topics
# Processing article 531... ✓ Found 3 topics
# Processing article 532... ✓ Found 2 topics
# Processing article 533... ✓ Found 2 topics
# Processing article 534... ✓ Found 1 topics
# Processing article 535... ✓ Found 1 topics
# Processing article 536... ✓ Found 1 topics
# Processing article 537... ✓ Found 5 topics
# Processing article 538... ✓ Found 5 topics
# Processing article 539... ✓ Found 3 topics
# Processing article 540... ✓ Found 0 topics
# Processing article 541... ✓ Found 3 topics
# Processing article 542... ✓ Found 5 topics
# Processing article 543... ✓ Found 0 topics
# Processing article 544... ✓ Found 4 topics
# Processing article 545... ✓ Found 4 topics
# Processing article 546... ✓ Found 4 topics
# Processing article 547... ✓ Found 5 topics
# Processing article 548... ✓ Found 2 topics
# Processing article 549... ✓ Found 1 topics
# Processing article 550... ✓ Found 2 topics
# Processing article 551... ✓ Found 0 topics
# Processing article 552... ✓ Found 2 topics
# Processing article 553... ✓ Found 1 topics
# Processing article 554... ✓ Found 1 topics
# Processing article 555... ✓ Found 2 topics
# Processing article 556... ✓ Found 2 topics
# Processing article 557... ✓ Found 5 topics
# Processing article 558... ✓ Found 2 topics
# Processing article 559... ✓ Found 4 topics
# Processing article 560... ✓ Found 2 topics
# Processing article 561... ✓ Found 0 topics
# Processing article 562... ✓ Found 1 topics
# Processing article 563... ✓ Found 3 topics
# Processing article 564... ✓ Found 5 topics
# Processing article 565... ✓ Found 1 topics
# Processing article 566... ✓ Found 1 topics
# Processing article 567... ✓ Found 1 topics
# Processing article 568... ✓ Found 1 topics
# Processing article 569... ✓ Found 3 topics
# Processing article 570... ✓ Found 0 topics
# Processing article 571... ✓ Found 5 topics
# Processing article 572... ✓ Found 4 topics
# Processing article 573... ✓ Found 3 topics
# Processing article 574... ✓ Found 2 topics
# Processing article 575... ✓ Found 5 topics
# Processing article 576... ✓ Found 5 topics
# Processing article 577... ✓ Found 5 topics
# Processing article 578... ✓ Found 5 topics
# Processing article 579... ✓ Found 1 topics
# Processing article 580... ✓ Found 4 topics
# Processing article 581... ✓ Found 0 topics
# Processing article 582... ✓ Found 2 topics
# Processing article 583... ✓ Found 4 topics
# Processing article 584... ✓ Found 3 topics
# Processing article 585... ✓ Found 1 topics
# Processing article 586... ✓ Found 4 topics
# Processing article 587... ✓ Found 2 topics
# Processing article 588... ✓ Found 3 topics
# Processing article 589... ✓ Found 5 topics
# Processing article 590... ✓ Found 5 topics
# Processing article 591... ✓ Found 1 topics
# Processing article 592... ✓ Found 4 topics
# Processing article 593... ✓ Found 4 topics
# Processing article 594... ✓ Found 4 topics
# Processing article 595... ✓ Found 5 topics
# Processing article 596... ✓ Found 2 topics
# Processing article 597... ✓ Found 0 topics
# Processing article 598... ✓ Found 0 topics
# Processing article 599... ✓ Found 4 topics
# Processing article 600... ✓ Found 3 topics
# Processing article 601... ✓ Found 2 topics
# Processing article 602... ✓ Found 1 topics
# Processing article 603... ✓ Found 3 topics
# Processing article 604... ✓ Found 2 topics
# Processing article 605... ✓ Found 5 topics
# Processing article 606... ✓ Found 1 topics
# Processing article 607... ✓ Found 3 topics
# Processing article 608... ✓ Found 3 topics
# Processing article 609... ✓ Found 5 topics
# Processing article 610... ✓ Found 0 topics
# Processing article 611... ✓ Found 1 topics
# Processing article 612... ✓ Found 1 topics
# Processing article 613... ✓ Found 3 topics
# Processing article 614... ✓ Found 2 topics
# Processing article 615... ✓ Found 1 topics
# Processing article 616... ✓ Found 3 topics
# Processing article 617... ✓ Found 2 topics
# Processing article 618... ✓ Found 4 topics
# Processing article 619... ✓ Found 3 topics
# Processing article 620... ✓ Found 5 topics
# Processing article 621... ✓ Found 1 topics
# Processing article 622... ✓ Found 5 topics
# Processing article 623... ✓ Found 3 topics
# Processing article 624... ✓ Found 1 topics
# Processing article 625... ✓ Found 5 topics
# Processing article 626... ✓ Found 5 topics
# Processing article 627... ✓ Found 1 topics
# Processing article 628... ✓ Found 3 topics
# Processing article 629... ✓ Found 1 topics
# Processing article 630... ✓ Found 1 topics
# Processing article 631... ✓ Found 5 topics
# Processing article 632... ✓ Found 1 topics
# Processing article 633... ✓ Found 5 topics
# Processing article 634... ✓ Found 1 topics
# Processing article 635... ✓ Found 0 topics
# Processing article 636... ✓ Found 2 topics
# Processing article 637... ✓ Found 2 topics
# Processing article 638... ✓ Found 3 topics
# Processing article 639... ✓ Found 4 topics
# Processing article 640... ✓ Found 4 topics
# Processing article 641... ✓ Found 1 topics
# Processing article 642... ✓ Found 2 topics
# Processing article 643... ✓ Found 3 topics
# Processing article 644... ✓ Found 2 topics
# Processing article 645... ✓ Found 5 topics
# Processing article 646... ✓ Found 3 topics
# Processing article 647... ✓ Found 0 topics
# Processing article 648... ✓ Found 4 topics
# Processing article 649... ✓ Found 1 topics
# Processing article 650... ✓ Found 2 topics
# Processing article 651... ✓ Found 1 topics
# Processing article 652... ✓ Found 0 topics
# Processing article 653... ✓ Found 2 topics
# Processing article 654... ✓ Found 1 topics
# Processing article 655... ✓ Found 2 topics
# Processing article 656... ✓ Found 5 topics
# Processing article 657... ✓ Found 3 topics
# Processing article 658... ✓ Found 2 topics
# Processing article 659... ✓ Found 1 topics
# Processing article 660... ✓ Found 2 topics
# Processing article 661... ✓ Found 0 topics
# Processing article 662... ✓ Found 0 topics
# Processing article 663... ✓ Found 3 topics
# Processing article 664... ✓ Found 2 topics
# Processing article 665... ✓ Found 2 topics
# Processing article 666... ✓ Found 2 topics
# Processing article 667... ✓ Found 2 topics
# Processing article 668... ✓ Found 1 topics
# Processing article 669... ✓ Found 1 topics
# Processing article 670... ✓ Found 1 topics
# Processing article 671... ✓ Found 3 topics
# Processing article 672... ✓ Found 1 topics
# Processing article 673... ✓ Found 2 topics
# Processing article 674... ✓ Found 2 topics
# Processing article 675... ✓ Found 2 topics
# Processing article 676... ✓ Found 1 topics
# Processing article 677... ✓ Found 2 topics
# Processing article 678... ✓ Found 2 topics
# Processing article 679... ✓ Found 2 topics
# Processing article 680... ✓ Found 3 topics
# Processing article 681... ✓ Found 2 topics
# Processing article 682... ✓ Found 0 topics
# Processing article 683... ✓ Found 1 topics
# Processing article 684... ✓ Found 3 topics
# Processing article 685... ✓ Found 1 topics
# Processing article 686... ✓ Found 2 topics
# Processing article 687... ✓ Found 1 topics
# Processing article 688... ✓ Found 2 topics
# Processing article 689... ✓ Found 3 topics
# Processing article 690... ✓ Found 3 topics
# Processing article 691... ✓ Found 1 topics
# Processing article 692... ✓ Found 2 topics
# Processing article 693... ✓ Found 2 topics
# Processing article 694... ✓ Found 5 topics
# Processing article 695... ✓ Found 1 topics
# Processing article 696... ✓ Found 3 topics
# Processing article 697... ✓ Found 3 topics
# Processing article 698... ✓ Found 4 topics
# Processing article 699... ✓ Found 1 topics
# Processing article 700... ✓ Found 2 topics
# Processing article 701... ✓ Found 3 topics
# Processing article 702... ✓ Found 1 topics
# Processing article 703... ✓ Found 2 topics
# Processing article 704... ✓ Found 5 topics
# Processing article 705... ✓ Found 3 topics
# Processing article 706... ✓ Found 5 topics
# Processing article 707... ✓ Found 1 topics
# Processing article 708... ✓ Found 2 topics
# Processing article 709... ✓ Found 3 topics
# Processing article 710... ✓ Found 2 topics
# Processing article 711... ✓ Found 3 topics
# Processing article 712... ✓ Found 2 topics
# Processing article 713... ✓ Found 0 topics
# Processing article 714... ✓ Found 1 topics
# Processing article 715... ✓ Found 1 topics
# Processing article 716... ✓ Found 1 topics
# Processing article 717... ✓ Found 2 topics
# Processing article 718... ✓ Found 1 topics
# Processing article 719... ✓ Found 2 topics
# Processing article 720... ✓ Found 3 topics
# Processing article 721... ✓ Found 4 topics
# Processing article 722... ✓ Found 5 topics
# Processing article 723... ✓ Found 5 topics
# Processing article 724... ✓ Found 3 topics
# Processing article 725... ✓ Found 2 topics
# Processing article 726... ✓ Found 3 topics
# Processing article 727... ✓ Found 1 topics
# Processing article 728... ✓ Found 3 topics
# Processing article 729... ✓ Found 2 topics
# Processing article 730... ✓ Found 2 topics
# Processing article 731... ✓ Found 3 topics
# Processing article 732... ✓ Found 3 topics
# Processing article 733... ✓ Found 3 topics
# Processing article 734... ✓ Found 3 topics
# Processing article 735... ✓ Found 3 topics
# Processing article 736... ✓ Found 4 topics
# Processing article 737... ✓ Found 3 topics
# Processing article 738... ✓ Found 1 topics
# Processing article 739... ✓ Found 3 topics
# Processing article 740... ✓ Found 1 topics
# Processing article 741... ✓ Found 2 topics
# Processing article 742... ✓ Found 1 topics
# Processing article 743... ✓ Found 4 topics
# Processing article 744... ✓ Found 1 topics
# Processing article 745... ✓ Found 2 topics
# Processing article 746... ✓ Found 0 topics
# Processing article 747... ✓ Found 2 topics
# Processing article 748... ✓ Found 3 topics
# Processing article 749... ✓ Found 1 topics
# Processing article 750... ✓ Found 0 topics
# Processing article 751... ✓ Found 2 topics
# Processing article 752... ✓ Found 2 topics
# Processing article 753... ✓ Found 0 topics
# Processing article 754... ✓ Found 4 topics
# Processing article 755... ✓ Found 3 topics
# Processing article 756... ✓ Found 4 topics
# Processing article 757... ✓ Found 2 topics
# Processing article 758... ✓ Found 4 topics
# Processing article 759... ✓ Found 4 topics
# Processing article 760... ✓ Found 4 topics
# Processing article 761... ✓ Found 4 topics
# Processing article 762... ✓ Found 5 topics
# Processing article 763... ✓ Found 1 topics
# Processing article 764... ✓ Found 2 topics
# Processing article 765... ✓ Found 5 topics
# Processing article 766... ✓ Found 2 topics
# Processing article 767... ✓ Found 4 topics
# Processing article 768... ✓ Found 4 topics
# Processing article 769... ✓ Found 4 topics
# Processing article 770... ✓ Found 3 topics
# Processing article 771... ✓ Found 1 topics
# Processing article 772... ✓ Found 1 topics
# Processing article 773... ✓ Found 2 topics
# Processing article 774... ✓ Found 5 topics
# Processing article 775... ✓ Found 3 topics
# Processing article 776... ✓ Found 2 topics
# Processing article 777... ✓ Found 5 topics
# Processing article 778... ✓ Found 2 topics
# Processing article 779... ✓ Found 2 topics
# Processing article 780... ✓ Found 3 topics
# Processing article 781... ✓ Found 3 topics
# Processing article 782... ✓ Found 3 topics
# Processing article 783... ✓ Found 1 topics
# Processing article 784... ✓ Found 0 topics
# Processing article 785... ✓ Found 4 topics
# Processing article 786... ✓ Found 4 topics
# Processing article 787... ✓ Found 1 topics
# Processing article 788... ✓ Found 3 topics
# Processing article 789... ✓ Found 5 topics
# Processing article 790... ✓ Found 2 topics
# Processing article 791... ✓ Found 3 topics
# Processing article 792... ✓ Found 2 topics
# Processing article 793... ✓ Found 4 topics
# Processing article 794... ✓ Found 3 topics
# Processing article 795... ✓ Found 1 topics
# Processing article 796... ✓ Found 5 topics
# Processing article 797... ✓ Found 2 topics
# Processing article 798... ✓ Found 2 topics
# Processing article 799... ✓ Found 4 topics
# Processing article 800... ✓ Found 4 topics
# Processing article 801... ✓ Found 1 topics
# Processing article 802... ✓ Found 5 topics
# Processing article 803... ✓ Found 5 topics
# Processing article 804... ✓ Found 3 topics
# Processing article 805... ✓ Found 1 topics
# Processing article 806... ✓ Found 2 topics
# Processing article 807... ✓ Found 5 topics
# Processing article 808... ✓ Found 2 topics
# Processing article 809... ✓ Found 3 topics
# Processing article 810... ✓ Found 5 topics
# Processing article 811... ✓ Found 5 topics
# Processing article 812... ✓ Found 3 topics
# Processing article 813... ✓ Found 3 topics
# Processing article 814... ✓ Found 5 topics
# Processing article 815... ✓ Found 5 topics
# Processing article 816... ✓ Found 1 topics
# Processing article 817... ✓ Found 5 topics
# Processing article 818... ✓ Found 1 topics
# Processing article 819... ✓ Found 2 topics
# Processing article 820... ✓ Found 2 topics
# Processing article 821... ✓ Found 2 topics
# Processing article 822... ✓ Found 4 topics
# Processing article 823... ✓ Found 2 topics
# Processing article 824... ✓ Found 2 topics
# Processing article 825... ✓ Found 1 topics
# Processing article 826... ✓ Found 4 topics
# Processing article 827... ✓ Found 3 topics
# Processing article 828... ✓ Found 5 topics
# Processing article 829... ✓ Found 4 topics
# Processing article 830... ✓ Found 4 topics
# Processing article 831... ✓ Found 3 topics
# Processing article 832... ✓ Found 5 topics
# Processing article 833... ✓ Found 0 topics
# Processing article 834... ✓ Found 5 topics
# Processing article 835... ✓ Found 1 topics
# Processing article 836... ✓ Found 2 topics
# Processing article 837... ✓ Found 5 topics
# Processing article 838... ✓ Found 2 topics
# Processing article 839... ✓ Found 0 topics
# Processing article 840... ✓ Found 2 topics
# Processing article 841... ✓ Found 0 topics
# Processing article 842... ✓ Found 2 topics
# Processing article 843... ✓ Found 2 topics
# Processing article 844... ✓ Found 2 topics
# Processing article 845... ✓ Found 1 topics
# Processing article 846... ✓ Found 3 topics
# Processing article 847... ✓ Found 5 topics
# Processing article 848... ✓ Found 5 topics
# Processing article 849... ✓ Found 1 topics
# Processing article 850... ✓ Found 2 topics
# Processing article 851... ✓ Found 5 topics
# Processing article 852... ✓ Found 2 topics
# Processing article 853... ✓ Found 2 topics
# Processing article 854... ✓ Found 5 topics
# Processing article 855... ✓ Found 5 topics
# Processing article 856... ✓ Found 3 topics
# Processing article 857... ✓ Found 5 topics
# Processing article 858... ✓ Found 4 topics
# Processing article 859... ✓ Found 3 topics
# Processing article 860... ✓ Found 2 topics
# Processing article 861... ✓ Found 0 topics
# Processing article 862... ✓ Found 3 topics
# Processing article 863... ✓ Found 0 topics
# Processing article 864... ✓ Found 2 topics
# Processing article 865... ✓ Found 4 topics
# Processing article 866... ✓ Found 4 topics
# Processing article 867... ✓ Found 4 topics
# Processing article 868... ✓ Found 5 topics
# Processing article 869... ✓ Found 3 topics
# Processing article 870... ✓ Found 3 topics
# Processing article 871... ✓ Found 4 topics
# Processing article 872... ✓ Found 2 topics
# Processing article 873... ✓ Found 5 topics
# Processing article 874... ✓ Found 5 topics
# Processing article 875... ✓ Found 5 topics
# Processing article 876... ✓ Found 1 topics
# Processing article 877... ✓ Found 1 topics
# Processing article 878... ✓ Found 2 topics
# Processing article 879... ✓ Found 2 topics
# Processing article 880... ✓ Found 0 topics
# Processing article 881... ✓ Found 2 topics
# Processing article 882... ✓ Found 3 topics
# Processing article 883... ✓ Found 1 topics
# Processing article 884... ✓ Found 2 topics
# Processing article 885... ✓ Found 5 topics
# Processing article 886... ✓ Found 1 topics
# Processing article 887... ✓ Found 3 topics
# Processing article 888... ✓ Found 2 topics
# Processing article 889... ✓ Found 2 topics
# Processing article 890... ✓ Found 3 topics
# Processing article 891... ✓ Found 0 topics
# Processing article 892... ✓ Found 5 topics
# Processing article 893... ✓ Found 0 topics
# Processing article 894... ✓ Found 2 topics
# Processing article 895... ✓ Found 3 topics
# Processing article 896... ✓ Found 2 topics
# Processing article 897... ✓ Found 0 topics
# Processing article 898... ✓ Found 0 topics
# Processing article 899... ✓ Found 3 topics
# Processing article 900... ✓ Found 3 topics
# Processing article 901... ✓ Found 2 topics
# Processing article 902... ✓ Found 1 topics
# Processing article 903... ✓ Found 2 topics
# Processing article 904... ✓ Found 4 topics
# Processing article 905... ✓ Found 2 topics
# Processing article 906... ✓ Found 3 topics
# Processing article 907... ✓ Found 2 topics
# Processing article 908... ✓ Found 3 topics
# Processing article 909... ✓ Found 2 topics
# Processing article 910... ✓ Found 1 topics
# Processing article 911... ✓ Found 3 topics
# Processing article 912... ✓ Found 0 topics
# Processing article 913... ✓ Found 4 topics
# Processing article 914... ✓ Found 1 topics
# Processing article 915... ✓ Found 3 topics
# Processing article 916... ✓ Found 3 topics
# Processing article 917... ✓ Found 5 topics
# Processing article 918... ✓ Found 5 topics
# Processing article 919... ✓ Found 4 topics
# Processing article 920... ✓ Found 3 topics
# Processing article 921... ✓ Found 2 topics
# Processing article 922... ✓ Found 1 topics
# Processing article 923... ✓ Found 2 topics
# Processing article 924... ✓ Found 4 topics
# Processing article 925... ✓ Found 3 topics
# Processing article 926... ✓ Found 1 topics
# Processing article 927... ✓ Found 2 topics
# Processing article 928... ✓ Found 1 topics
# Processing article 929... ✓ Found 5 topics
# Processing article 930... ✓ Found 2 topics
# Processing article 931... ✓ Found 1 topics
# Processing article 932... ✓ Found 2 topics
# Processing article 933... ✓ Found 1 topics
# Processing article 934... ✓ Found 2 topics
# Processing article 935... ✓ Found 1 topics
# Processing article 936... ✓ Found 3 topics
# Processing article 937... ✓ Found 3 topics
# Processing article 938... ✓ Found 5 topics
# Processing article 939... ✓ Found 0 topics
# Processing article 940... ✓ Found 3 topics
# Processing article 941... ✓ Found 5 topics
# Processing article 942... ✓ Found 2 topics
# Processing article 943... ✓ Found 4 topics
# Processing article 944... ✓ Found 0 topics
# Processing article 945... ✓ Found 2 topics
# Processing article 946... ✓ Found 5 topics
# Processing article 947... ✓ Found 0 topics
# Processing article 948... ✓ Found 3 topics
# Processing article 949... ✓ Found 3 topics
# Processing article 950... ✓ Found 5 topics
# Processing article 951... ✓ Found 3 topics
# Processing article 952... ✓ Found 2 topics
# Processing article 953... ✓ Found 2 topics
# Processing article 954... ✓ Found 1 topics
# Processing article 955... ✓ Found 2 topics
# Processing article 956... ✓ Found 4 topics
# Processing article 957... ✓ Found 1 topics
# Processing article 958... ✓ Found 5 topics
# Processing article 959... ✓ Found 1 topics
# Processing article 960... ✓ Found 4 topics
# Processing article 961... ✓ Found 3 topics
# Processing article 962... ✓ Found 3 topics
# Processing article 963... ✓ Found 4 topics
# Processing article 964... ✓ Found 3 topics
# Processing article 965... ✓ Found 3 topics
# Processing article 966... ✓ Found 1 topics
# Processing article 967... ✓ Found 1 topics
# Processing article 968... ✓ Found 4 topics
# Processing article 969... ✓ Found 2 topics
# Processing article 970... ✓ Found 4 topics
# Processing article 971... ✓ Found 2 topics
# Processing article 972... ✓ Found 2 topics
# Processing article 973... ✓ Found 2 topics
# Processing article 974... ✓ Found 3 topics
# Processing article 975... ✓ Found 1 topics
# Processing article 976... ✓ Found 4 topics
# Processing article 977... ✓ Found 5 topics
# Processing article 978... ✓ Found 0 topics
# Processing article 979... ✓ Found 1 topics
# Processing article 980... ✓ Found 2 topics
# Processing article 981... ✓ Found 1 topics
# Processing article 982... ✓ Found 5 topics
# Processing article 983... ✓ Found 1 topics
# Processing article 984... ✓ Found 4 topics
# Processing article 985... ✓ Found 2 topics
# Processing article 986... ✓ Found 2 topics
# Processing article 987... ✓ Found 5 topics
# Processing article 988... ✓ Found 2 topics
# Processing article 989... ✓ Found 3 topics
# Processing article 990... ✓ Found 1 topics
# Processing article 991... ✓ Found 2 topics
# Processing article 992... ✓ Found 3 topics
# Processing article 993... ✓ Found 2 topics
# Processing article 994... ✓ Found 2 topics
# Processing article 995... ✓ Found 1 topics
# Processing article 996... ✓ Found 5 topics
# Processing article 997... ✓ Found 1 topics
# Processing article 998... ✓ Found 2 topics
# Processing article 999... ✓ Found 3 topics
# Processing article 1000... ✓ Found 5 topics
# Processing article 1001... ✓ Found 4 topics
# Processing article 1002... ✓ Found 3 topics
# Processing article 1003... ✓ Found 3 topics
# Processing article 1004... ✓ Found 4 topics
# Processing article 1005... ✓ Found 4 topics
# Processing article 1006... ✓ Found 4 topics
# Processing article 1007... ✓ Found 1 topics
# Processing article 1008... ✓ Found 2 topics
# Processing article 1009... ✓ Found 2 topics
# Processing article 1010... ✓ Found 2 topics
# Processing article 1011... ✓ Found 1 topics
# Processing article 1012... ✓ Found 1 topics
# Processing article 1013... ✓ Found 3 topics
# Processing article 1014... ✓ Found 3 topics
# Processing article 1015... ✓ Found 3 topics
# Processing article 1016... ✓ Found 2 topics
# Processing article 1017... ✓ Found 4 topics
# Processing article 1018... ✓ Found 1 topics
# Processing article 1019... ✓ Found 2 topics
# Processing article 1020... ✓ Found 3 topics
# Processing article 1021... ✓ Found 2 topics
# Processing article 1022... ✓ Found 2 topics
# Processing article 1023... ✓ Found 4 topics
# Processing article 1024... ✓ Found 2 topics
# Processing article 1025... ✓ Found 2 topics
# Processing article 1026... ✓ Found 2 topics
# Processing article 1027... ✓ Found 1 topics
# Processing article 1028... ✓ Found 2 topics
# Processing article 1029... ✓ Found 5 topics
# Processing article 1030... ✓ Found 5 topics
# Processing article 1031... ✓ Found 3 topics
# Processing article 1032... ✓ Found 2 topics
# Processing article 1033... ✓ Found 3 topics
# Processing article 1034... ✓ Found 1 topics
# Processing article 1035... ✓ Found 1 topics
# Processing article 1036... ✓ Found 1 topics
# Processing article 1037... ✓ Found 2 topics
# Processing article 1038... ✓ Found 3 topics
# Processing article 1039... ✓ Found 3 topics
# Processing article 1040... ✓ Found 2 topics
# Processing article 1041... ✓ Found 1 topics
# Processing article 1042... ✓ Found 5 topics
# Processing article 1043... ✓ Found 3 topics
# Processing article 1044... ✓ Found 1 topics
# Processing article 1045... ✓ Found 2 topics
# Processing article 1046... ✓ Found 5 topics
# Processing article 1047... ✓ Found 1 topics
# Processing article 1048... ✓ Found 1 topics
# Processing article 1049... ✓ Found 3 topics
# Processing article 1050... ✓ Found 2 topics
# Processing article 1051... ✓ Found 2 topics
# Processing article 1052... ✓ Found 1 topics
# Processing article 1053... ✓ Found 5 topics
# Processing article 1054... ✓ Found 3 topics
# Processing article 1055... ✓ Found 2 topics
# Processing article 1056... ✓ Found 1 topics
# Processing article 1057... ✓ Found 1 topics
# Processing article 1058... ✓ Found 4 topics
# Processing article 1059... ✓ Found 5 topics
# Processing article 1060... ✓ Found 0 topics
# Processing article 1061... ✓ Found 0 topics
# Processing article 1062... ✓ Found 0 topics
# Processing article 1063... ✓ Found 0 topics
# Processing article 1064... ✓ Found 3 topics
# Processing article 1065... ✓ Found 3 topics
# Processing article 1066... ✓ Found 2 topics
# Processing article 1067... ✓ Found 4 topics
# Processing article 1068... ✓ Found 2 topics
# Processing article 1069... ✓ Found 2 topics
# Processing article 1070... ✓ Found 1 topics
# Processing article 1071... ✓ Found 1 topics
# Processing article 1072... ✓ Found 4 topics
# Processing article 1073... ✓ Found 5 topics
# Processing article 1074... ✓ Found 2 topics
# Processing article 1075... ✓ Found 4 topics
# Processing article 1076... ✓ Found 5 topics
# Processing article 1077... ✓ Found 0 topics
# Processing article 1078... ✓ Found 2 topics
# Processing article 1079... ✓ Found 2 topics
# Processing article 1080... ✓ Found 4 topics
# Processing article 1081... ✓ Found 2 topics
# Processing article 1082... ✓ Found 5 topics
# Processing article 1083... ✓ Found 3 topics
# Processing article 1084... ✓ Found 1 topics
# Processing article 1085... ✓ Found 1 topics
# Processing article 1086... ✓ Found 5 topics
# Processing article 1087... ✓ Found 3 topics
# Processing article 1088... ✓ Found 2 topics
# Processing article 1089... ✓ Found 3 topics
# Processing article 1090... ✓ Found 1 topics
# Processing article 1091... ✓ Found 2 topics
# Processing article 1092... ✓ Found 3 topics
# Processing article 1093... ✓ Found 3 topics
# Processing article 1094... ✓ Found 2 topics
# Processing article 1095... ✓ Found 1 topics
# Processing article 1096... ✓ Found 4 topics
# Processing article 1097... ✓ Found 3 topics
# Processing article 1098... ✓ Found 4 topics
# Processing article 1099... ✓ Found 1 topics
# Processing article 1100... ✓ Found 0 topics
# Processing article 1101... ✓ Found 5 topics
# Processing article 1102... ✓ Found 4 topics
# Processing article 1103... ✓ Found 4 topics
# Processing article 1104... ✓ Found 1 topics
# Processing article 1105... ✓ Found 1 topics
# Processing article 1106... ✓ Found 5 topics
# Processing article 1107... ✓ Found 3 topics
# Processing article 1108... ✓ Found 1 topics
# Processing article 1109... ✓ Found 0 topics
# ...
# Processing article 1478... ✓ Found 1 topics
# Processing article 1479... ✓ Found 2 topics
# Processing article 1480... ✓ Found 5 topics
# Processing article 1481... ✓ Found 1 topics
# Processing article 1482... ✓ Found 5 topics
# Processing article 1483... ✓ Found 3 topics
# Processing article 1484... ✓ Found 5 topics
# Processing article 1485... ✓ Found 4 topics
# Processing article 1486... ✓ Found 3 topics
# Processing article 1487... ✓ Found 4 topics
# Processing article 1488... ✓ Found 5 topics
# Processing article 1489... ✓ Found 1 topics
# Processing article 1490... ✓ Found 2 topics
# Processing article 1491... ✓ Found 0 topics
# Processing article 1492... ✓ Found 2 topics
# Processing article 1493... ✓ Found 3 topics
# Processing article 1494... ✓ Found 5 topics
# Processing article 1495... ✓ Found 0 topics
# Processing article 1496... ✓ Found 5 topics
# Processing article 1497... ✓ Found 4 topics
# Processing article 1498... ✓ Found 1 topics
# Processing article 1499... ✓ Found 3 topics
# Processing article 1500... ✓ Found 3 topics
# Processing article 1501... ✓ Found 3 topics
# Processing article 1502... ✓ Found 2 topics
# Processing article 1503... ✓ Found 2 topics
# Processing article 1504... ✓ Found 3 topics
# Processing article 1505... ✓ Found 0 topics
# Processing article 1506... ✓ Found 1 topics
# Processing article 1507... ✓ Found 1 topics
# Processing article 1508... ✓ Found 4 topics
# Processing article 1509... ✓ Found 2 topics
# Processing article 1510... ✓ Found 5 topics
# Processing article 1511... ✓ Found 4 topics
# Processing article 1512... ✓ Found 2 topics
# Processing article 1513... ✓ Found 3 topics
# Processing article 1514... ✓ Found 1 topics
# Processing article 1515... ✓ Found 3 topics
# Processing article 1516... ✓ Found 0 topics
# Processing article 1517... ✓ Found 1 topics
# Processing article 1518... ✓ Found 3 topics
# Processing article 1519... ✓ Found 2 topics
# Processing article 1520... ✓ Found 3 topics
# Processing article 1521... ✓ Found 1 topics
# Processing article 1522... ✓ Found 1 topics
# Processing article 1523... ✓ Found 1 topics
# Processing article 1524... ✓ Found 2 topics
# Processing article 1525... ✓ Found 5 topics
# Processing article 1526... ✓ Found 4 topics
# Processing article 1527... ✓ Found 2 topics
# Processing article 1528... ✓ Found 3 topics
# Processing article 1529... ✓ Found 3 topics
# Processing article 1530... ✓ Found 1 topics
# Processing article 1531... ✓ Found 5 topics
# Processing article 1532... ✓ Found 1 topics
# Processing article 1533... ✓ Found 2 topics
# Processing article 1534... ✓ Found 2 topics
# Processing article 1535... ✓ Found 2 topics
# Processing article 1536... ✓ Found 5 topics
# Processing article 1537... ✓ Found 3 topics
# Processing article 1538... ✓ Found 5 topics
# Processing article 1539... ✓ Found 1 topics
# Processing article 1540... ✓ Found 3 topics
# Processing article 1541... ✓ Found 2 topics
# Processing article 1542... ✓ Found 5 topics
# Processing article 1543... ✓ Found 2 topics
# Processing article 1544... ✓ Found 4 topics
# Processing article 1545... ✓ Found 3 topics
# Processing article 1546... ✓ Found 5 topics
# Processing article 1547... ✓ Found 2 topics
# Processing article 1548... ✓ Found 1 topics
# Processing article 1549... ✓ Found 3 topics
# Processing article 1550... ✓ Found 3 topics
# Processing article 1551... ✓ Found 5 topics
# Processing article 1552... ✓ Found 2 topics
# Processing article 1553... ✓ Found 4 topics
# Processing article 1554... ✓ Found 3 topics
# Processing article 1555... ✓ Found 0 topics
# Processing article 1556... ✓ Found 3 topics
# Processing article 1557... ✓ Found 4 topics
# Processing article 1558... ✓ Found 2 topics
# Processing article 1559... ✓ Found 2 topics
# Processing article 1560... ✓ Found 1 topics
# Processing article 1561... ✓ Found 1 topics
# Processing article 1562... ✓ Found 5 topics
# Processing article 1563... ✓ Found 5 topics
# Processing article 1564... ✓ Found 5 topics
# Processing article 1565... ✓ Found 4 topics
# Processing article 1566... ✓ Found 3 topics
# Processing article 1567... ✓ Found 2 topics
# Processing article 1568... ✓ Found 5 topics
# Processing article 1569... ✓ Found 1 topics
# Processing article 1570... ✓ Found 5 topics
# Processing article 1571... ✓ Found 1 topics
# Processing article 1572... ✓ Found 1 topics
# Processing article 1573... ✓ Found 2 topics
# Processing article 1574... ✓ Found 1 topics
# Processing article 1575... ✓ Found 1 topics
# Processing article 1576... ✓ Found 3 topics
# Processing article 1577... ✓ Found 2 topics
# Processing article 1578... ✓ Found 5 topics
# Processing article 1579... ✓ Found 1 topics
# Processing article 1580... ✓ Found 1 topics
# Processing article 1581... ✓ Found 5 topics
# Processing article 1582... ✓ Found 2 topics
# Processing article 1583... ✓ Found 2 topics
# Processing article 1584... ✓ Found 4 topics
# Processing article 1585... ✓ Found 2 topics
# Processing article 1586... ✓ Found 3 topics
# Processing article 1587... ✓ Found 1 topics
# Processing article 1588... ✓ Found 1 topics
# Processing article 1589... ✓ Found 1 topics
# Processing article 1590... ✓ Found 1 topics
# Processing article 1591... ✓ Found 5 topics
# Processing article 1592... ✓ Found 4 topics
# Processing article 1593... ✓ Found 1 topics
# Processing article 1594... ✓ Found 3 topics
# Processing article 1595... ✓ Found 5 topics
# Processing article 1596... ✓ Found 2 topics
# Processing article 1597... ✓ Found 4 topics
# Processing article 1598... ✓ Found 5 topics
# Processing article 1599... ✓ Found 1 topics
# Processing article 1600... ✓ Found 2 topics
# Processing article 1601... ✓ Found 2 topics
# Processing article 1602... ✓ Found 5 topics
# Processing article 1603... ✓ Found 1 topics
# Processing article 1604... ✓ Found 1 topics
# Processing article 1605... ✓ Found 1 topics
# Processing article 1606... ✓ Found 4 topics
# Processing article 1607... ✓ Found 1 topics
# Processing article 1608... ✓ Found 2 topics
# Processing article 1609... ✓ Found 3 topics
# Processing article 1610... ✓ Found 1 topics
# Processing article 1611... ✓ Found 0 topics
# Processing article 1612... ✓ Found 0 topics
# Processing article 1613... ✓ Found 2 topics
# Processing article 1614... ✓ Found 4 topics
# Processing article 1615... ✓ Found 5 topics
# Processing article 1616... ✓ Found 2 topics
# Processing article 1617... ✓ Found 0 topics
# Processing article 1618... ✓ Found 2 topics
# Processing article 1619... ✓ Found 4 topics
# Processing article 1620... ✓ Found 5 topics
# Processing article 1621... ✓ Found 4 topics
# Processing article 1622... ✓ Found 5 topics
# Processing article 1623... ✓ Found 3 topics
# Processing article 1624... ✓ Found 5 topics
# Processing article 1625... ✓ Found 2 topics
# Processing article 1626... ✓ Found 5 topics
# Processing article 1627... ✓ Found 2 topics
# Processing article 1628... ✓ Found 3 topics
# Processing article 1629... ✓ Found 2 topics
# Processing article 1630... ✓ Found 0 topics
# Processing article 1631... ✓ Found 2 topics
# Processing article 1632... ✓ Found 5 topics
# Processing article 1633... ✓ Found 5 topics
# Processing article 1634... ✓ Found 5 topics
# Processing article 1635... ✓ Found 2 topics
# Processing article 1636... ✓ Found 1 topics
# Processing article 1637... ✓ Found 4 topics
# Processing article 1638... ✓ Found 1 topics
# Processing article 1639... ✓ Found 2 topics
# Processing article 1640... ✓ Found 1 topics
# Processing article 1641... ✓ Found 2 topics
# Processing article 1642... ✓ Found 1 topics
# Processing article 1643... ✓ Found 2 topics
# Processing article 1644... ✓ Found 2 topics
# Processing article 1645... ✓ Found 1 topics
# Processing article 1646... ✓ Found 0 topics
# Processing article 1647... ✓ Found 1 topics
# Processing article 1648... ✓ Found 2 topics
# Processing article 1649... ✓ Found 1 topics
# Processing article 1650... ✓ Found 1 topics
# Processing article 1651... ✓ Found 1 topics
# Processing article 1652... ✓ Found 2 topics
# Processing article 1653... ✓ Found 3 topics
# Processing article 1654... ✓ Found 2 topics
# Processing article 1655... ✓ Found 5 topics
# Processing article 1656... ✓ Found 2 topics
# Processing article 1657... ✓ Found 2 topics
# Processing article 1658... ✓ Found 2 topics
# Processing article 1659... ✓ Found 4 topics
# Processing article 1660... ✓ Found 1 topics
# Processing article 1661... ✓ Found 5 topics
# Processing article 1662... ✓ Found 3 topics
# Processing article 1663... ✓ Found 1 topics
# Processing article 1664... ✓ Found 1 topics
# Processing article 1665... ✓ Found 1 topics
# Processing article 1666... ✓ Found 1 topics
# Processing article 1667... ✓ Found 2 topics
# Processing article 1668... ✓ Found 4 topics
# Processing article 1669... ✓ Found 2 topics
# Processing article 1670... ✓ Found 4 topics
# Processing article 1671... ✓ Found 1 topics
# Processing article 1672... ✓ Found 0 topics
# Processing article 1673... ✓ Found 1 topics
# Processing article 1674... ✓ Found 2 topics
# Processing article 1675... ✓ Found 1 topics
# Processing article 1676... ✓ Found 1 topics
# Processing article 1677... ✓ Found 5 topics
# Processing article 1678... ✓ Found 5 topics
# Processing article 1679... ✓ Found 5 topics
# Processing article 1680... ✓ Found 3 topics
# Processing article 1681... ✓ Found 0 topics
# Processing article 1682... ✓ Found 1 topics
# Processing article 1683... ✓ Found 3 topics
# Processing article 1684... ✓ Found 1 topics
# Processing article 1685... ✓ Found 2 topics
# Processing article 1686... ✓ Found 2 topics
# Processing article 1687... ✓ Found 5 topics
# Processing article 1688... ✓ Found 1 topics
# Processing article 1689... ✓ Found 2 topics
# Processing article 1690... ✓ Found 3 topics
# Processing article 1691... ✓ Found 4 topics
# Processing article 1692... ✓ Found 3 topics
# Processing article 1693... ✓ Found 2 topics
# Processing article 1694... ✓ Found 1 topics
# Processing article 1695... ✓ Found 4 topics
# Processing article 1696... ✓ Found 1 topics
# Processing article 1697... ✓ Found 2 topics
# Processing article 1698... ✓ Found 1 topics
# Processing article 1699... ✓ Found 1 topics
# Processing article 1700... ✓ Found 1 topics
# Processing article 1701... ✓ Found 3 topics
# Processing article 1702... ✓ Found 2 topics
# Processing article 1703... ✓ Found 3 topics
# Processing article 1704... ✓ Found 1 topics
# Processing article 1705... ✓ Found 2 topics
# Processing article 1706... ✓ Found 0 topics
# Processing article 1707... ✓ Found 1 topics
# Processing article 1708... ✓ Found 3 topics
# Processing article 1709... ✓ Found 1 topics
# Processing article 1710... ✓ Found 2 topics
# Processing article 1711... ✓ Found 1 topics
# Processing article 1712... ✓ Found 3 topics
# Processing article 1713... ✓ Found 2 topics
# Processing article 1714... ✓ Found 4 topics
# Processing article 1715... ✓ Found 0 topics
# Processing article 1716... ✓ Found 2 topics
# Processing article 1717... ✓ Found 0 topics
# Processing article 1718... ✓ Found 1 topics
# Processing article 1719... ✓ Found 1 topics
# Processing article 1720... ✓ Found 4 topics
# Processing article 1721... ✓ Found 5 topics
# Processing article 1722... ✓ Found 1 topics
# Processing article 1723... ✓ Found 1 topics
# Processing article 1724... ✓ Found 2 topics
# Processing article 1725... ✓ Found 2 topics
# Processing article 1726... ✓ Found 4 topics
# Processing article 1727... ✓ Found 2 topics
# Processing article 1728... ✓ Found 0 topics
# Processing article 1729... ✓ Found 0 topics
# Processing article 1730... ✓ Found 1 topics
# Processing article 1731... ✓ Found 3 topics
# Processing article 1732... ✓ Found 2 topics
# Processing article 1733... ✓ Found 1 topics
# Processing article 1734... ✓ Found 2 topics
# Processing article 1735... ✓ Found 4 topics
# Processing article 1736... ✓ Found 1 topics
# Processing article 1737... ✓ Found 3 topics
# Processing article 1738... ✓ Found 1 topics
# Processing article 1739... ✓ Found 8 topics
# Processing article 1740... ✓ Found 1 topics
# Processing article 1741... ✓ Found 1 topics
# Processing article 1742... ✓ Found 1 topics
# Processing article 1743... ✓ Found 5 topics
# Processing article 1744... ✓ Found 3 topics
# Processing article 1745... ✓ Found 5 topics
# Processing article 1746... ✓ Found 3 topics
# Processing article 1747... ✓ Found 1 topics
# Processing article 1748... ✓ Found 5 topics
# Processing article 1749... ✓ Found 5 topics
# Processing article 1750... ✓ Found 5 topics
# Processing article 1751... ✓ Found 2 topics
# Processing article 1752... ✓ Found 2 topics
# Processing article 1753... ✓ Found 3 topics
# Processing article 1754... ✓ Found 4 topics
# Processing article 1755... ✓ Found 3 topics
# Processing article 1756... ✓ Found 3 topics
# Processing article 1757... ✓ Found 2 topics
# Processing article 1758... ✓ Found 5 topics
# Processing article 1759... ✓ Found 2 topics
# Processing article 1760... ✓ Found 1 topics
# Processing article 1761... ✓ Found 2 topics
# Processing article 1762... ✓ Found 3 topics
# Processing article 1763... ✓ Found 2 topics
# Processing article 1764... ✓ Found 1 topics
# Processing article 1765... ✓ Found 5 topics
# Processing article 1766... ✓ Found 9 topics
# Processing article 1767... ✓ Found 1 topics
# Processing article 1768... ✓ Found 2 topics
# Processing article 1769... ✓ Found 4 topics
# Processing article 1770... ✓ Found 1 topics
# Processing article 1771... ✓ Found 1 topics
# Processing article 1772... ✓ Found 2 topics
# Processing article 1773... ✓ Found 2 topics
# Processing article 1774... ✓ Found 2 topics
# Processing article 1775... ✓ Found 2 topics
# Processing article 1776... ✓ Found 1 topics
# Processing article 1777... ✓ Found 2 topics
# Processing article 1778... ✓ Found 1 topics
# Processing article 1779... ✓ Found 4 topics
# Processing article 1780... ✓ Found 3 topics
# Processing article 1781... ✓ Found 4 topics
# Processing article 1782... ✓ Found 3 topics
# Processing article 1783... ✓ Found 2 topics
# Processing article 1784... ✓ Found 5 topics
# Processing article 1785... ✓ Found 3 topics
# Processing article 1786... ✓ Found 0 topics
# Processing article 1787... ✓ Found 1 topics
# Processing article 1788... ✓ Found 4 topics
# Processing article 1789... ✓ Found 5 topics
# Processing article 1790... ✓ Found 4 topics
# Processing article 1791... ✓ Found 1 topics
# Processing article 1792... ✓ Found 0 topics
# Processing article 1793... ✓ Found 1 topics
# Processing article 1794... ✓ Found 2 topics
# Processing article 1795... ✓ Found 2 topics
# Processing article 1796... ✓ Found 2 topics
# Processing article 1797... ✓ Found 1 topics
# Processing article 1798... ✓ Found 2 topics
# Processing article 1799... ✓ Found 2 topics
# Processing article 1800... ✓ Found 1 topics
# Processing article 1801... ✓ Found 5 topics
# Processing article 1802... ✓ Found 3 topics
# Processing article 1803... ✓ Found 5 topics
# Processing article 1804... ✓ Found 1 topics
# Processing article 1805... ✓ Found 3 topics
# Processing article 1806... ✓ Found 2 topics
# Processing article 1807... ✓ Found 2 topics
# Processing article 1808... ✓ Found 1 topics
# Processing article 1809... ✓ Found 3 topics
# Processing article 1810... ✓ Found 3 topics
#
# ================================================================================
# CLASSIFICATION RESULTS SUMMARY
# ================================================================================
#
# Total articles: 1811
# Articles with topics: 1698 (93.8%)
# Multi-label articles: 1243 (68.6%)
#
# ================================================================================
# TOP 10 MOST FREQUENT TOPICS
# ================================================================================
#
# ✓ Results saved to /kaggle/working/topic_classification_results.json
# ✓ CSV exported to /kaggle/working/topic_classification_results.csv
#
# ================================================================================
# SAMPLE RESULTS (First 3)
# ================================================================================
#
# Article 0:
#   Preview:  a quick update to the new zen nx ?
# ...
#   True: []
#   Predicted: ['design', 'hardware', 'software']
#
# Article 1:
#   Preview: this is an edited review , now that i have had time to use the device .
# ...
#   True: ['use']
#   Predicted: ['design', 'hardware', 'software', 'sound', 'storage']
#
# Article 2:
#   Preview: while , there are flaws with the machine , the xtra gets five stars because of its affordability .
# ...
#   True: ['player', 'price']
#   Predicted: ['price', 'hardware', 'use', 'warranty']

# %%
# ============================================================================
# EVALUATION: Compare Predicted vs True Concepts
# ============================================================================

def evaluate_classification(results: List[Dict]) -> Dict:
    """
    Calculate accuracy metrics by comparing predicted topics with true concepts.
    """
    total = len(results)
    exact_match = 0  # All predicted topics match exactly with true concepts
    partial_match = 0  # At least one topic matches
    no_match = 0  # No topics match
    no_true_labels = 0  # Articles with no true concepts
    
    all_precisions = []
    all_recalls = []
    all_f1s = []
    
    correct_predictions = []
    incorrect_predictions = []
    
    for result in results:
        true_set = set([c.lower().strip() for c in result['true_concepts']]) if result['true_concepts'] else set()
        pred_set = set(result['predicted_topics'])
        
        # Skip articles with no true labels
        if len(true_set) == 0:
            no_true_labels += 1
            continue
        
        # Find intersection
        intersection = true_set & pred_set
        
        # Exact match
        if true_set == pred_set and len(true_set) > 0:
            exact_match += 1
            correct_predictions.append(result)
        elif len(intersection) > 0:
            partial_match += 1
        else:
            no_match += 1
            incorrect_predictions.append(result)
        
        # Calculate precision, recall, F1
        if len(pred_set) > 0:
            precision = len(intersection) / len(pred_set)
            all_precisions.append(precision)
        else:
            all_precisions.append(0)
        
        if len(true_set) > 0:
            recall = len(intersection) / len(true_set)
            all_recalls.append(recall)
        else:
            all_recalls.append(0)
        
        if all_precisions[-1] + all_recalls[-1] > 0:
            f1 = 2 * (all_precisions[-1] * all_recalls[-1]) / (all_precisions[-1] + all_recalls[-1])
            all_f1s.append(f1)
        else:
            all_f1s.append(0)
    
    articles_with_true_labels = total - no_true_labels
    
    metrics = {
        'total_articles': total,
        'articles_with_true_labels': articles_with_true_labels,
        'articles_without_true_labels': no_true_labels,
        'exact_matches': exact_match,
        'partial_matches': partial_match,
        'no_matches': no_match,
        'exact_match_rate': exact_match / articles_with_true_labels if articles_with_true_labels > 0 else 0,
        'partial_match_rate': partial_match / articles_with_true_labels if articles_with_true_labels > 0 else 0,
        'avg_precision': np.mean(all_precisions) if all_precisions else 0,
        'avg_recall': np.mean(all_recalls) if all_recalls else 0,
        'avg_f1': np.mean(all_f1s) if all_f1s else 0,
        'correct_examples': correct_predictions[:3],
        'incorrect_examples': incorrect_predictions[:3]
    }
    
    # Print results
    print(f"\n{'='*80}")
    print("EVALUATION METRICS")
    print(f"{'='*80}")
    print(f"\nTotal articles evaluated: {articles_with_true_labels}")
    print(f"Articles without labels (skipped): {no_true_labels}")
    print(f"\n📊 ACCURACY:")
    print(f"  ✓ Exact matches: {exact_match} ({metrics['exact_match_rate']*100:.1f}%)")
    print(f"  ~ Partial matches: {partial_match} ({metrics['partial_match_rate']*100:.1f}%)")
    print(f"  ✗ No matches: {no_match} ({no_match/articles_with_true_labels*100:.1f}%)")
    print(f"\n📈 PERFORMANCE METRICS:")
    print(f"  Precision: {metrics['avg_precision']:.3f} (how many predicted topics were correct)")
    print(f"  Recall: {metrics['avg_recall']:.3f} (how many true topics were found)")
    print(f"  F1 Score: {metrics['avg_f1']:.3f} (overall accuracy)")
    
    return metrics


# Run evaluation
print("\nEvaluating classification accuracy...")
eval_metrics = evaluate_classification(results)

# Show correct examples
print(f"\n{'='*80}")
print("✓ CORRECTLY CLASSIFIED EXAMPLES")
print(f"{'='*80}")
for ex in eval_metrics['correct_examples']:
    print(f"\nArticle {ex['article_id']}:")
    print(f"  True: {ex['true_concepts']}")
    print(f"  Predicted: {ex['predicted_topics']}")
    print(f"  ✓ EXACT MATCH!")

# Show incorrect examples
print(f"\n{'='*80}")
print("✗ INCORRECTLY CLASSIFIED EXAMPLES")
print(f"{'='*80}")
for ex in eval_metrics['incorrect_examples']:
    print(f"\nArticle {ex['article_id']}:")
    print(f"  True: {ex['true_concepts']}")
    print(f"  Predicted: {ex['predicted_topics']}")
    #print(f"  Reasoning: {ex['reasoning'][:150]}...")
# Out:
# Evaluating classification accuracy...
#
# ================================================================================
# EVALUATION METRICS
# ================================================================================
#
# Total articles evaluated: 1174
# Articles without labels (skipped): 637
#
# 📊 ACCURACY:
#   ✓ Exact matches: 307 (26.1%)
#   ~ Partial matches: 615 (52.4%)
#   ✗ No matches: 252 (21.5%)
#
# 📈 PERFORMANCE METRICS:
#   Precision: 0.539 (how many predicted topics were correct)
#   Recall: 0.673 (how many true topics were found)
#   F1 Score: 0.557 (overall accuracy)
#
# ================================================================================
# ✓ CORRECTLY CLASSIFIED EXAMPLES
# ================================================================================
#
# Article 13:
#   True: ['player']
#   Predicted: ['player']
#   ✓ EXACT MATCH!
#
# Article 19:
#   True: ['software']
#   Predicted: ['software']
#   ✓ EXACT MATCH!
#
# Article 27:
#   True: ['price']
#   Predicted: ['price']
#   ✓ EXACT MATCH!
#
# ================================================================================
# ✗ INCORRECTLY CLASSIFIED EXAMPLES
# ================================================================================
#
# Article 1:
#   True: ['use']
#   Predicted: ['design', 'hardware', 'software', 'sound', 'storage']
#
# Article 8:
#   True: ['player']
#   Predicted: ['design', 'hardware', 'price', 'sound', 'storage']
#
# Article 16:
#   True: ['transfer']
#   Predicted: ['player', 'storage', 'use']

# %%
# ============================================================================
# EVALUATION METRICS (Following the Paper's Methodology)
# ============================================================================

def calculate_metrics_paper_style(results: List[Dict]) -> Dict:
    """
    Calculate evaluation metrics following the paper's approach:
    "For each article, the model inferred topic(s) were compared against 
    the list of 'gold' topic(s) to compute the true positive, false positive, 
    and false negative statistics for that article. Then, all such statistics 
    for all the articles in a dataset were aggregated and used to compute 
    the final Precision, Recall, and micro-averaged F1 score."
    
    Reference: Section 5.4 of the paper
    """
    # Aggregate statistics across all articles
    total_tp = 0  # True Positives
    total_fp = 0  # False Positives
    total_fn = 0  # False Negatives
    
    articles_evaluated = 0
    articles_skipped = 0
    
    for result in results:
        # Get true and predicted topics (lowercased and stripped)
        true_topics = set([c.lower().strip() for c in result['true_concepts']]) if result['true_concepts'] else set()
        pred_topics = set([t.lower().strip() for t in result['predicted_topics']])
        
        # Skip articles with no ground truth labels
        if len(true_topics) == 0:
            articles_skipped += 1
            continue
        
        articles_evaluated += 1
        
        # Calculate TP, FP, FN for this article
        tp = len(true_topics & pred_topics)  # Intersection
        fp = len(pred_topics - true_topics)  # Predicted but not true
        fn = len(true_topics - pred_topics)  # True but not predicted
        
        # Aggregate
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
    # Calculate micro-averaged metrics
    precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0.0
    recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0.0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    
    metrics = {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'total_tp': total_tp,
        'total_fp': total_fp,
        'total_fn': total_fn,
        'articles_evaluated': articles_evaluated,
        'articles_skipped': articles_skipped
    }
    
    # Print results
    print(f"\n{'='*80}")
    print("EVALUATION METRICS (Paper's Methodology)")
    print(f"{'='*80}")
    print(f"\nArticles evaluated: {articles_evaluated}")
    print(f"Articles skipped (no ground truth): {articles_skipped}")
    print(f"\nAggregated Statistics:")
    print(f"  True Positives (TP): {total_tp}")
    print(f"  False Positives (FP): {total_fp}")
    print(f"  False Negatives (FN): {total_fn}")
    print(f"\n📊 MICRO-AVERAGED METRICS:")
    print(f"  Precision: {precision:.3f}")
    print(f"  Recall: {recall:.3f}")
    print(f"  F1 Score: {f1_score:.3f}")
    
    return metrics


# Run evaluation using the paper's methodology
print("\nEvaluating using paper's methodology...")
paper_metrics = calculate_metrics_paper_style(results)

# Compare with their baselines (from Table 6 in the paper)
print(f"\n{'='*80}")
print("COMPARISON WITH PAPER'S BASELINES")
print(f"{'='*80}")
print(f"This model's F1 Score: {paper_metrics['f1_score']:.3f}")
print(f"\nPaper's Results:")
print(f"  GFLM-S baseline: 0.532")
print(f"  GFLM-W baseline: 0.530")
print(f"  SBERT (best mid encoder): 0.594")
print(f"  ChatGPT-3.5 (best overall): 0.606")
# Out:
# Evaluating using paper's methodology...
#
# ================================================================================
# EVALUATION METRICS (Paper's Methodology)
# ================================================================================
#
# Articles evaluated: 1174
# Articles skipped (no ground truth): 637
#
# Aggregated Statistics:
#   True Positives (TP): 1128
#   False Positives (FP): 1457
#   False Negatives (FN): 604
#
# 📊 MICRO-AVERAGED METRICS:
#   Precision: 0.436
#   Recall: 0.651
#   F1 Score: 0.523
#
# ================================================================================
# COMPARISON WITH PAPER'S BASELINES
# ================================================================================
# This model's F1 Score: 0.523
#
# Paper's Results:
#   GFLM-S baseline: 0.532
#   GFLM-W baseline: 0.530
#   SBERT (best mid encoder): 0.594
#   ChatGPT-3.5 (best overall): 0.606

# %%
# ============================================================================
# STEP 3: LOAD KEYWORDS
# ============================================================================

# Load the keyword file
with open('/kaggle/input/keywords/Keyword_Creative.json', 'r') as f:
    keyword_data = json.load(f)

# Parse into dictionary: {topic_name: [keywords]}
concept_keywords = {}

for item in keyword_data:
    keywords_list = item['Keyword']
    topic_name = keywords_list[0].lower()  # First item is topic name
    related_keywords = [kw.lower() for kw in keywords_list[1:]]  # Rest are keywords
    concept_keywords[topic_name] = related_keywords

print(f"\n{'='*80}")
print("LOADED CONCEPT KEYWORDS")
print(f"{'='*80}")
print(f"Total concepts: {len(concept_keywords)}\n")

# Show first 3 examples
for i, (topic, keywords) in enumerate(list(concept_keywords.items())[:3]):
    print(f"{i+1}. {topic}:")
    print(f"   Keywords: {', '.join(keywords[:5])}{'...' if len(keywords) > 5 else ''}")
# Out:
# ================================================================================
# LOADED CONCEPT KEYWORDS
# ================================================================================
# Total concepts: 21
#
# 1. software:
#    Keywords: installation, explorer, folder_structure, program, setup...
# 2. player:
#    Keywords: creative, nomad, zen, xtra
# 3. sound:
#    Keywords: audio, headphone, earbud, earphone, equalizer...

# %%
# ============================================================================
# STEP 4: BUILD CONCEPT KNOWLEDGE GRAPHS
# ============================================================================

class ConceptKGBuilder:
    """Build knowledge graphs for concepts using topic names and keywords."""
    
    def __init__(self):
        self.concept_kgs = {}
    
    def build_concept_kg(self, topic_name: str, keywords: List[str]) -> nx.DiGraph:
        """Build a KG for a single concept."""
        G = nx.DiGraph()
        
        # Add topic as central node
        G.add_node(topic_name, node_type='topic')
        
        # Add keywords and connect to topic
        for keyword in keywords:
            G.add_node(keyword, node_type='keyword')
            G.add_edge(topic_name, keyword, relation='has_keyword')
        
        # Connect keywords to each other (co-occurrence)
        for i, kw1 in enumerate(keywords):
            for kw2 in keywords[i+1:]:
                G.add_edge(kw1, kw2, relation='co_occurs')
        
        return G
    
    def build_all_concept_kgs(self, concept_keywords: Dict[str, List[str]]) -> Dict[str, nx.DiGraph]:
        """Build KGs for all concepts."""
        for topic, keywords in concept_keywords.items():
            self.concept_kgs[topic] = self.build_concept_kg(topic, keywords)
        
        print(f"\n{'='*80}")
        print("BUILT CONCEPT KNOWLEDGE GRAPHS")
        print(f"{'='*80}")
        print(f"Total concept KGs: {len(self.concept_kgs)}")
        
        # Show stats
        for topic, kg in list(self.concept_kgs.items())[:3]:
            print(f"  {topic}: {kg.number_of_nodes()} nodes, {kg.number_of_edges()} edges")
        
        return self.concept_kgs

# Build concept KGs
kg_builder = ConceptKGBuilder()
concept_kgs = kg_builder.build_all_concept_kgs(concept_keywords)
# Out:
# ================================================================================
# BUILT CONCEPT KNOWLEDGE GRAPHS
# ================================================================================
# Total concept KGs: 21
#   software: 11 nodes, 55 edges
#   player: 5 nodes, 10 edges
#   sound: 10 nodes, 45 edges

# %%
# ============================================================================
# STEP 5: GRAPH EMBEDDER
# ============================================================================

class GraphEmbedder:
    """Embed graphs using Graph2Vec."""
    
    def __init__(self, dimensions=128, wl_iterations=3):
        """
        Args:
            dimensions: Embedding dimension
            wl_iterations: Weisfeiler-Lehman iterations
        """
        self.dimensions = dimensions
        self.model = Graph2Vec(
            dimensions=dimensions,
            wl_iterations=wl_iterations,
            epochs=100,
            min_count=1
        )
        print(f"\n✓ Initialized Graph2Vec (dim={dimensions}, WL={wl_iterations})")
    
    def embed_graphs(self, graphs: List[nx.Graph]) -> np.ndarray:
        """
        Embed multiple graphs.
        
        Args:
            graphs: List of NetworkX graphs
        
        Returns:
            Embedding matrix (n_graphs × dimensions)
        """
        # Convert to undirected (Graph2Vec requires undirected)
        undirected = [G.to_undirected() if G.is_directed() else G for G in graphs]
        
        # Fit and get embeddings
        self.model.fit(undirected)
        embeddings = self.model.get_embedding()
        
        return embeddings
    
    def embed_single_graph(self, G: nx.Graph, reference_graphs: List[nx.Graph]) -> np.ndarray:
        """
        Embed a single new graph using reference graphs.
        
        Args:
            G: Graph to embed
            reference_graphs: Graphs to fit model on
        
        Returns:
            Single embedding vector
        """
        # Combine reference graphs with new graph
        all_graphs = reference_graphs + [G]
        embeddings = self.embed_graphs(all_graphs)
        
        # Return embedding of the last graph (the new one)
        return embeddings[-1]

print("✓ GraphEmbedder class defined")
# Out:
# ✓ GraphEmbedder class defined

# %%
# ============================================================================
# STEP 6: GRAPH-BASED TOPIC CLASSIFIER
# ============================================================================

class GraphTopicClassifier:
    """Classify articles using graph embeddings."""
    
    def __init__(self, 
                 concept_kgs: Dict[str, nx.DiGraph],
                 embedding_dim: int = 128,
                 threshold: float = 0.3):
        """
        Initialize classifier.
        
        Args:
            concept_kgs: Dictionary of concept KGs
            embedding_dim: Embedding dimension
            threshold: Similarity threshold for topic assignment
        """
        self.concept_kgs = concept_kgs
        self.threshold = threshold
        
        print(f"\n{'='*80}")
        print("INITIALIZING GRAPH-BASED CLASSIFIER")
        print(f"{'='*80}")
        
        # Initialize embedder
        self.embedder = GraphEmbedder(dimensions=embedding_dim)
        
        # Prepare concept graphs
        self.concept_names = list(concept_kgs.keys())
        concept_graphs = [concept_kgs[name] for name in self.concept_names]
        
        # Embed all concept graphs
        print("\nEmbedding concept knowledge graphs...")
        self.concept_embeddings = self.embedder.embed_graphs(concept_graphs)
        
        print(f"✓ Embedded {len(self.concept_names)} concept graphs")
        print(f"  Embedding shape: {self.concept_embeddings.shape}")
        print(f"  Similarity threshold: {threshold}")
        
        # Store as dictionary
        self.concept_embedding_dict = {
            name: self.concept_embeddings[i] 
            for i, name in enumerate(self.concept_names)
        }
    
    def _dict_to_graph(self, kg_dict: Dict) -> nx.DiGraph:
        """Convert KG dictionary to NetworkX graph."""
        G = nx.DiGraph()
        
        # Add nodes from entities
        entities = kg_dict.get('entities', [])
        for entity in entities:
            G.add_node(entity)
        
        # Add edges from relations
        relations = kg_dict.get('relations', [])
        for relation in relations:
            if isinstance(relation, (list, tuple)) and len(relation) >= 3:
                source, rel_type, target = relation[0], relation[1], relation[2]
                G.add_edge(source, target, relation=rel_type)
        
        return G
    
    def classify_article(self, article_kg: Dict) -> Dict:
        """Classify a single article."""
        # Convert to graph
        G_article = self._dict_to_graph(article_kg)
        
        # Skip if empty
        if G_article.number_of_nodes() == 0:
            return {
                'predicted_topics': [],
                'similarities': {},
                'max_similarity': 0.0
            }
        
        # Embed article graph
        reference_graphs = [self.concept_kgs[name] for name in self.concept_names]
        article_embedding = self.embedder.embed_single_graph(
            G_article, 
            reference_graphs=reference_graphs
        )
        
        # Compute similarities with all concepts
        similarities = {}
        for topic_name in self.concept_names:
            concept_emb = self.concept_embedding_dict[topic_name]
            sim = cosine_similarity([article_embedding], [concept_emb])[0][0]
            similarities[topic_name] = float(sim)
        
        # Assign topics above threshold
        predicted_topics = [
            topic for topic, sim in similarities.items() 
            if sim >= self.threshold
        ]
        
        # Sort by similarity
        predicted_topics = sorted(
            predicted_topics, 
            key=lambda t: similarities[t], 
            reverse=True
        )
        
        return {
            'predicted_topics': predicted_topics,
            'similarities': similarities,
            'max_similarity': max(similarities.values()) if similarities else 0.0
        }
    
    def classify_dataset(self, 
                        articles: List[Dict],
                        knowledge_graphs: List[Dict]) -> List[Dict]:
        """Classify all articles."""
        results = []
        kg_dict = {kg['id']: kg for kg in knowledge_graphs}
        
        print(f"\n{'='*80}")
        print(f"CLASSIFYING {len(knowledge_graphs)} ARTICLES")
        print(f"{'='*80}\n")
        
        for idx in range(len(knowledge_graphs)):
            if idx % 20 == 0:
                print(f"Processing articles {idx}-{min(idx+20, len(knowledge_graphs))}...")
            
            article = articles[idx] if idx < len(articles) else {}
            article_kg = kg_dict.get(idx, {'entities': [], 'relations': []})
            
            # Skip if no KG
            if article_kg.get('num_edges', 0) == 0:
                results.append({
                    'article_id': idx,
                    'predicted_topics': [],
                    'similarities': {},
                    'max_similarity': 0.0,
                    'true_concepts': article.get('Concept', [])
                })
                continue
            
            # Classify
            classification = self.classify_article(article_kg)
            
            result = {
                'article_id': idx,
                'predicted_topics': classification['predicted_topics'],
                'similarities': classification['similarities'],
                'max_similarity': classification['max_similarity'],
                'true_concepts': article.get('Concept', [])
            }
            
            results.append(result)
        
        print("\n✓ Classification complete!")
        return results

print("✓ GraphTopicClassifier class defined")
# Out:
# ✓ GraphTopicClassifier class defined

# %%
# ============================================================================
# STEP 6: GRAPH-BASED TOPIC CLASSIFIER
# ============================================================================

class GraphTopicClassifier:
    """Classify articles using graph embeddings."""
    
    def __init__(self, 
                 concept_kgs: Dict[str, nx.DiGraph],
                 embedding_dim: int = 128,
                 threshold: float = 0.3):
        """
        Initialize classifier.
        
        Args:
            concept_kgs: Dictionary of concept KGs
            embedding_dim: Embedding dimension
            threshold: Similarity threshold for topic assignment
        """
        self.concept_kgs = concept_kgs
        self.threshold = threshold
        
        print(f"\n{'='*80}")
        print("INITIALIZING GRAPH-BASED CLASSIFIER")
        print(f"{'='*80}")
        
        # Initialize embedder
        self.embedder = GraphEmbedder(dimensions=embedding_dim)
        
        # Prepare concept graphs
        self.concept_names = list(concept_kgs.keys())
        concept_graphs = [concept_kgs[name] for name in self.concept_names]
        
        # Embed all concept graphs
        print("\nEmbedding concept knowledge graphs...")
        self.concept_embeddings = self.embedder.embed_graphs(concept_graphs)
        
        print(f"✓ Embedded {len(self.concept_names)} concept graphs")
        print(f"  Embedding shape: {self.concept_embeddings.shape}")
        print(f"  Similarity threshold: {threshold}")
        
        # Store as dictionary
        self.concept_embedding_dict = {
            name: self.concept_embeddings[i] 
            for i, name in enumerate(self.concept_names)
        }
    
    def _dict_to_graph(self, kg_dict: Dict) -> nx.DiGraph:
        """Convert KG dictionary to NetworkX graph."""
        G = nx.DiGraph()
        
        # Add nodes from entities
        entities = kg_dict.get('entities', [])
        for entity in entities:
            G.add_node(entity)
        
        # Add edges from relations
        relations = kg_dict.get('relations', [])
        for relation in relations:
            if isinstance(relation, (list, tuple)) and len(relation) >= 3:
                source, rel_type, target = relation[0], relation[1], relation[2]
                G.add_edge(source, target, relation=rel_type)
        
        return G
    
    def classify_article(self, article_kg: Dict) -> Dict:
        """Classify a single article."""
        # Convert to graph
        G_article = self._dict_to_graph(article_kg)
        
        # Skip if empty
        if G_article.number_of_nodes() == 0:
            return {
                'predicted_topics': [],
                'similarities': {},
                'max_similarity': 0.0
            }
        
        # Embed article graph
        reference_graphs = [self.concept_kgs[name] for name in self.concept_names]
        article_embedding = self.embedder.embed_single_graph(
            G_article, 
            reference_graphs=reference_graphs
        )
        
        # Compute similarities with all concepts
        similarities = {}
        for topic_name in self.concept_names:
            concept_emb = self.concept_embedding_dict[topic_name]
            sim = cosine_similarity([article_embedding], [concept_emb])[0][0]
            similarities[topic_name] = float(sim)
        
        # Assign topics above threshold
        predicted_topics = [
            topic for topic, sim in similarities.items() 
            if sim >= self.threshold
        ]
        
        # Sort by similarity
        predicted_topics = sorted(
            predicted_topics, 
            key=lambda t: similarities[t], 
            reverse=True
        )
        
        return {
            'predicted_topics': predicted_topics,
            'similarities': similarities,
            'max_similarity': max(similarities.values()) if similarities else 0.0
        }
    
    def classify_dataset(self, 
                        articles: List[Dict],
                        knowledge_graphs: List[Dict]) -> List[Dict]:
        """Classify all articles."""
        results = []
        kg_dict = {kg['id']: kg for kg in knowledge_graphs}
        
        print(f"\n{'='*80}")
        print(f"CLASSIFYING {len(knowledge_graphs)} ARTICLES")
        print(f"{'='*80}\n")
        
        for idx in range(len(knowledge_graphs)):
            if idx % 20 == 0:
                print(f"Processing articles {idx}-{min(idx+20, len(knowledge_graphs))}...")
            
            article = articles[idx] if idx < len(articles) else {}
            article_kg = kg_dict.get(idx, {'entities': [], 'relations': []})
            
            # Skip if no KG
            if article_kg.get('num_edges', 0) == 0:
                results.append({
                    'article_id': idx,
                    'predicted_topics': [],
                    'similarities': {},
                    'max_similarity': 0.0,
                    'true_concepts': article.get('Concept', [])
                })
                continue
            
            # Classify
            classification = self.classify_article(article_kg)
            
            result = {
                'article_id': idx,
                'predicted_topics': classification['predicted_topics'],
                'similarities': classification['similarities'],
                'max_similarity': classification['max_similarity'],
                'true_concepts': article.get('Concept', [])
            }
            
            results.append(result)
        
        print("\n✓ Classification complete!")
        return results

print("✓ GraphTopicClassifier class defined")
# Out:
# ✓ GraphTopicClassifier class defined

# %%
# !pip uninstall -y node2vec gensim smart_open
# !pip install smart_open==5.2.1 --force-reinstall
# !pip install gensim==4.3.2 --force-reinstall
# !pip install node2vec==0.4.6 --force-reinstall
# Out:
# Found existing installation: node2vec 0.4.6
# Uninstalling node2vec-0.4.6:
#   Successfully uninstalled node2vec-0.4.6
# Found existing installation: gensim 4.4.0
# Uninstalling gensim-4.4.0:
#   Successfully uninstalled gensim-4.4.0
# Found existing installation: smart-open 5.2.1
# Uninstalling smart-open-5.2.1:
#   Successfully uninstalled smart-open-5.2.1
# Collecting smart_open==5.2.1
#   Using cached smart_open-5.2.1-py3-none-any.whl.metadata (22 kB)
# Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Installing collected packages: smart_open
# Successfully installed smart_open-5.2.1
# Collecting gensim==4.3.2
#   Using cached gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting numpy>=1.18.5 (from gensim==4.3.2)
#   Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scipy>=1.7.0 (from gensim==4.3.2)
#   Using cached scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting smart-open>=1.8.1 (from gensim==4.3.2)
#   Using cached smart_open-7.4.4-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim==4.3.2)
#   Downloading wrapt-2.0.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (9.0 kB)
# Using cached gensim-4.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached numpy-2.3.4-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.9 MB)
# Using cached scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
# Using cached smart_open-7.4.4-py3-none-any.whl (63 kB)
# Downloading wrapt-2.0.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.1/114.1 kB 2.3 MB/s eta 0:00:00:00:01
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.0
#     Uninstalling wrapt-2.0.0:
#       Successfully uninstalled wrapt-2.0.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.2.1
#     Uninstalling smart-open-5.2.1:
#       Successfully uninstalled smart-open-5.2.1
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.3.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.4 which is incompatible.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.3.4 which is incompatible.
# ydata-profiling 4.17.0 requires scipy<1.16,>=1.4.1, but you have scipy 1.16.3 which is incompatible.
# deprecated 1.2.18 requires wrapt<2,>=1.10, but you have wrapt 2.0.1 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# scikit-image 0.25.2 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.4 which is incompatible.
# nx-cugraph-cu12 25.6.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.3.4 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed gensim-4.3.2 numpy-2.3.4 scipy-1.16.3 smart-open-7.4.4 wrapt-2.0.1
# Collecting node2vec==0.4.6
#   Using cached node2vec-0.4.6-py3-none-any.whl.metadata (743 bytes)
# Collecting gensim<5.0.0,>=4.1.2 (from node2vec==0.4.6)
#   Using cached gensim-4.4.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Collecting joblib<2.0.0,>=1.1.0 (from node2vec==0.4.6)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting networkx<3.0,>=2.5 (from node2vec==0.4.6)
#   Using cached networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting numpy<2.0.0,>=1.19.5 (from node2vec==0.4.6)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting tqdm<5.0.0,>=4.55.1 (from node2vec==0.4.6)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting scipy>=1.7.0 (from gensim<5.0.0,>=4.1.2->node2vec==0.4.6)
#   Using cached scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting smart_open>=1.8.1 (from gensim<5.0.0,>=4.1.2->node2vec==0.4.6)
#   Using cached smart_open-7.4.4-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart_open>=1.8.1->gensim<5.0.0,>=4.1.2->node2vec==0.4.6)
#   Using cached wrapt-2.0.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (9.0 kB)
# Using cached node2vec-0.4.6-py3-none-any.whl (7.0 kB)
# Using cached gensim-4.4.0-cp311-cp311-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.8 MB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached networkx-2.8.8-py3-none-any.whl (2.0 MB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached scipy-1.16.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.9 MB)
# Using cached smart_open-7.4.4-py3-none-any.whl (63 kB)
# Using cached wrapt-2.0.1-cp311-cp311-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (114 kB)
# Installing collected packages: wrapt, tqdm, numpy, networkx, joblib, smart_open, scipy, gensim, node2vec
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.1
#     Uninstalling wrapt-2.0.1:
#       Successfully uninstalled wrapt-2.0.1
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#   Attempting uninstall: networkx
#     Found existing installation: networkx 2.8.8
#     Uninstalling networkx-2.8.8:
#       Successfully uninstalled networkx-2.8.8
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.5.2
#     Uninstalling joblib-1.5.2:
#       Successfully uninstalled joblib-1.5.2
#   Attempting uninstall: smart_open
#     Found existing installation: smart_open 7.4.4
#     Uninstalling smart_open-7.4.4:
#       Successfully uninstalled smart_open-7.4.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.2
#     Uninstalling gensim-4.3.2:
#       Successfully uninstalled gensim-4.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 4.1.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# onnx 1.18.0 requires protobuf>=4.25.1, but you have protobuf 3.20.3 which is incompatible.
# ydata-profiling 4.17.0 requires scipy<1.16,>=1.4.1, but you have scipy 1.16.3 which is incompatible.
# deprecated 1.2.18 requires wrapt<2,>=1.10, but you have wrapt 2.0.1 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.40.3 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# bigframes 2.12.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.1.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# scikit-image 0.25.2 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.0a1 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# pandas-gbq 0.29.2 requires google-api-core<3.0.0,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# nx-cugraph-cu12 25.6.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# umap-learn 0.5.9.post2 requires scikit-learn>=1.6, but you have scikit-learn 1.2.2 which is incompatible.
# dataproc-spark-connect 0.8.3 requires google-api-core>=2.19, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed gensim-4.4.0 joblib-1.5.2 networkx-2.8.8 node2vec-0.4.6 numpy-1.26.4 scipy-1.16.3 smart_open-7.4.4 tqdm-4.67.1 wrapt-2.0.1

# %%
# !pip install smart_open==5.2.1 --force-reinstall
# Out:
# Collecting smart_open==5.2.1
#   Using cached smart_open-5.2.1-py3-none-any.whl.metadata (22 kB)
# Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# Installing collected packages: smart_open
#   Attempting uninstall: smart_open
#     Found existing installation: smart_open 7.4.4
#     Uninstalling smart_open-7.4.4:
#       Successfully uninstalled smart_open-7.4.4
# Successfully installed smart_open-5.2.1

# %%
import os, sys
os._exit(0)

# %%
import json
import numpy as np
import networkx as nx
from typing import List, Dict
from node2vec import Node2Vec
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

print("✓ Starting Multi-Label Article Classifier\n")
# Out:
# ✓ Starting Multi-Label Article Classifier

# %%
# ============================================================================
# STEP 1: GRAPH EMBEDDER
# ============================================================================

class GraphEmbedder:
    """Embed graphs using Node2Vec."""
    
    def __init__(self, dimensions=128, walk_length=30, num_walks=200):
        self.dimensions = dimensions
        self.walk_length = walk_length
        self.num_walks = num_walks
        print(f"✓ Initialized Node2Vec embedder (dim={dimensions})")
    
    def embed_graph(self, G: nx.Graph) -> np.ndarray:
        """Embed a single graph."""
        # Convert to undirected
        G_undirected = G.to_undirected() if G.is_directed() else G
        
        # Skip if too small
        if G_undirected.number_of_nodes() < 2:
            return np.zeros(self.dimensions)
        
        try:
            # Fit Node2Vec
            node2vec = Node2Vec(
                G_undirected, 
                dimensions=self.dimensions,
                walk_length=self.walk_length,
                num_walks=self.num_walks,
                workers=1,
                quiet=True
            )
            
            model = node2vec.fit(window=10, min_count=1, batch_words=4)
            
            # Get embeddings for all nodes
            node_embeddings = []
            for node in G_undirected.nodes():
                node_embeddings.append(model.wv[str(node)])
            
            # Average all node embeddings to get graph embedding
            graph_embedding = np.mean(node_embeddings, axis=0)
            return graph_embedding
        except:
            return np.zeros(self.dimensions)
    
    def embed_graphs(self, graphs: List[nx.Graph]) -> np.ndarray:
        """Embed multiple graphs."""
        embeddings = []
        for i, G in enumerate(graphs):
            if i % 5 == 0:
                print(f"  Embedding graph {i+1}/{len(graphs)}...")
            emb = self.embed_graph(G)
            embeddings.append(emb)
        return np.array(embeddings)

# %%
# ============================================================================
# STEP 2: MULTI-LABEL GRAPH CLASSIFIER
# ============================================================================

class MultiLabelGraphClassifier:
    """Multi-label classifier using graph embeddings."""
    
    def __init__(self, 
                 concept_kgs: Dict[str, nx.DiGraph],
                 embedding_dim: int = 128,
                 threshold: float = 0.5,  # Increased from 0.3
                 top_k: int = 3):  # Max labels per article
        """
        Initialize classifier.
        
        Args:
            concept_kgs: Dictionary of concept knowledge graphs
            embedding_dim: Embedding dimension
            threshold: Minimum similarity threshold (increased to 0.5)
            top_k: Maximum number of topics to assign per article
        """
        self.concept_kgs = concept_kgs
        self.threshold = threshold
        self.top_k = top_k
        
        print(f"\n{'='*80}")
        print("INITIALIZING MULTI-LABEL GRAPH CLASSIFIER")
        print(f"{'='*80}")
        
        # Initialize embedder
        self.embedder = GraphEmbedder(dimensions=embedding_dim)
        
        # Prepare concept graphs
        self.concept_names = list(concept_kgs.keys())
        concept_graphs = [concept_kgs[name] for name in self.concept_names]
        
        # Embed all concept graphs
        print("\nEmbedding concept knowledge graphs...")
        self.concept_embeddings = self.embedder.embed_graphs(concept_graphs)
        
        print(f"\n✓ Embedded {len(self.concept_names)} concept graphs")
        print(f"  Embedding shape: {self.concept_embeddings.shape}")
        print(f"  Absolute threshold: {threshold}")
        print(f"  Top-K limit: {self.top_k}")
        print(f"  Relative gap threshold: 0.15")
        
        # Store as dictionary
        self.concept_embedding_dict = {
            name: self.concept_embeddings[i] 
            for i, name in enumerate(self.concept_names)
        }
    
    def _dict_to_graph(self, kg_dict: Dict) -> nx.DiGraph:
        """Convert KG dictionary to NetworkX graph."""
        G = nx.DiGraph()
        
        # Add nodes from entities
        entities = kg_dict.get('entities', [])
        for entity in entities:
            G.add_node(entity)
        
        # Add edges from relations
        relations = kg_dict.get('relations', [])
        for relation in relations:
            if isinstance(relation, (list, tuple)) and len(relation) >= 3:
                source, rel_type, target = relation[0], relation[1], relation[2]
                G.add_edge(source, target, relation=rel_type)
        
        return G
    
    def classify_article(self, article_kg: Dict, top_k: int = 3) -> Dict:
        """
        Classify a single article (multi-label).
        
        Strategy: Use adaptive thresholding to prevent overprediction.
        - Apply absolute threshold
        - Take top-K only
        - Use relative threshold (gap from max)
        
        Args:
            article_kg: Article knowledge graph dictionary
            top_k: Maximum number of labels to assign
        """
        # Convert to graph
        G_article = self._dict_to_graph(article_kg)
        
        # Skip if empty
        if G_article.number_of_nodes() == 0:
            return {
                'predicted_topics': [],
                'similarities': {},
                'max_similarity': 0.0
            }
        
        # Embed article graph
        article_embedding = self.embedder.embed_graph(G_article)
        
        # Compute similarities with all concepts
        similarities = {}
        for topic_name in self.concept_names:
            concept_emb = self.concept_embedding_dict[topic_name]
            sim = cosine_similarity([article_embedding], [concept_emb])[0][0]
            similarities[topic_name] = float(sim)
        
        # Get sorted topics by similarity
        sorted_topics = sorted(similarities.items(), key=lambda x: x[1], reverse=True)
        
        # Strategy 1: Absolute threshold
        candidates = [(topic, sim) for topic, sim in sorted_topics if sim >= self.threshold]
        
        if len(candidates) == 0:
            return {
                'predicted_topics': [],
                'similarities': similarities,
                'max_similarity': max(similarities.values()) if similarities else 0.0
            }
        
        # Strategy 2: Top-K limit (prevent overprediction)
        candidates = candidates[:top_k]
        
        # Strategy 3: Relative threshold (gap detection)
        # Only keep topics within 0.15 similarity of the best match
        max_sim = candidates[0][1]
        relative_threshold = max_sim - 0.35
        
        predicted_topics = [
            topic for topic, sim in candidates
            if sim >= relative_threshold
        ]
        
        return {
            'predicted_topics': predicted_topics,
            'similarities': similarities,
            'max_similarity': max(similarities.values()) if similarities else 0.0
        }
    
    def classify_dataset(self, 
                        articles: List[Dict],
                        knowledge_graphs: List[Dict]) -> List[Dict]:
        """Classify all articles."""
        results = []
        kg_dict = {kg['id']: kg for kg in knowledge_graphs}
        
        print(f"\n{'='*80}")
        print(f"CLASSIFYING {len(knowledge_graphs)} ARTICLES (MULTI-LABEL)")
        print(f"{'='*80}\n")
        
        for idx in range(len(knowledge_graphs)):
            if idx % 20 == 0:
                print(f"Processing articles {idx}-{min(idx+20, len(knowledge_graphs))}...")
            
            article = articles[idx] if idx < len(articles) else {}
            article_kg = kg_dict.get(idx, {'entities': [], 'relations': []})
            
            # Skip if no KG
            if article_kg.get('num_edges', 0) == 0:
                results.append({
                    'article_id': idx,
                    'predicted_topics': [],
                    'similarities': {},
                    'max_similarity': 0.0,
                    'true_concepts': article.get('Concept', [])
                })
                continue
            
            # Classify (multi-label)
            classification = self.classify_article(article_kg)
            
            result = {
                'article_id': idx,
                'predicted_topics': classification['predicted_topics'],
                'num_predicted': len(classification['predicted_topics']),
                'similarities': classification['similarities'],
                'max_similarity': classification['max_similarity'],
                'true_concepts': article.get('Concept', [])
            }
            
            results.append(result)
        
        print("\n✓ Classification complete!")
        return results

# %%
# ============================================================================
# STEP 3: EVALUATION METRICS
# ============================================================================

def calculate_metrics(results: List[Dict]) -> Dict:
    """
    Calculate multi-label classification metrics.
    Uses micro-averaged precision, recall, F1.
    """
    total_tp = 0
    total_fp = 0
    total_fn = 0
    
    articles_evaluated = 0
    articles_skipped = 0
    
    multi_label_count = 0
    single_label_count = 0
    no_label_count = 0
    
    for result in results:
        true_topics = set([c.lower().strip() for c in result['true_concepts']]) if result['true_concepts'] else set()
        pred_topics = set([t.lower().strip() for t in result['predicted_topics']])
        
        if len(true_topics) == 0:
            articles_skipped += 1
            continue
        
        articles_evaluated += 1
        
        # Count label distribution
        if len(pred_topics) == 0:
            no_label_count += 1
        elif len(pred_topics) == 1:
            single_label_count += 1
        else:
            multi_label_count += 1
        
        tp = len(true_topics & pred_topics)
        fp = len(pred_topics - true_topics)
        fn = len(true_topics - pred_topics)
        
        total_tp += tp
        total_fp += fp
        total_fn += fn
    
    precision = total_tp / (total_tp + total_fp) if (total_tp + total_fp) > 0 else 0.0
    recall = total_tp / (total_tp + total_fn) if (total_tp + total_fn) > 0 else 0.0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    
    metrics = {
        'precision': precision,
        'recall': recall,
        'f1_score': f1_score,
        'total_tp': total_tp,
        'total_fp': total_fp,
        'total_fn': total_fn,
        'articles_evaluated': articles_evaluated,
        'articles_skipped': articles_skipped,
        'multi_label_count': multi_label_count,
        'single_label_count': single_label_count,
        'no_label_count': no_label_count
    }
    
    print(f"\n{'='*80}")
    print("EVALUATION METRICS (Micro-Averaged)")
    print(f"{'='*80}")
    print(f"\nArticles evaluated: {articles_evaluated}")
    print(f"Articles skipped (no ground truth): {articles_skipped}")
    print(f"\nLabel Distribution:")
    print(f"  No labels: {no_label_count} ({no_label_count/articles_evaluated*100:.1f}%)")
    print(f"  Single label: {single_label_count} ({single_label_count/articles_evaluated*100:.1f}%)")
    print(f"  Multi-label: {multi_label_count} ({multi_label_count/articles_evaluated*100:.1f}%)")
    print(f"\nAggregated Statistics:")
    print(f"  True Positives (TP): {total_tp}")
    print(f"  False Positives (FP): {total_fp}")
    print(f"  False Negatives (FN): {total_fn}")
    print(f"\n📊 PERFORMANCE:")
    print(f"  Precision: {precision:.3f}")
    print(f"  Recall: {recall:.3f}")
    print(f"  F1 Score: {f1_score:.3f}")
    
    # Comparison with baselines
    print(f"\n{'='*80}")
    print("COMPARISON WITH PAPER BASELINES (Medical Dataset)")
    print(f"{'='*80}")
    print(f"  This model:           F1 = {f1_score:.3f}")
    print(f"  GFLM-S baseline:      F1 = 0.532")
    print(f"  GFLM-W baseline:      F1 = 0.530")
    print(f"  SBERT:                F1 = 0.594")
    print(f"  ChatGPT-3.5:          F1 = 0.606")
    
    return metrics

# %%
# ============================================================================
# STEP 4: RUN CLASSIFICATION
# ============================================================================

print("\n" + "="*80)
print("RUNNING MULTI-LABEL CLASSIFICATION")
print("="*80)

# Initialize classifier with concept KGs
classifier = MultiLabelGraphClassifier(
    concept_kgs=concept_kgs,
    embedding_dim=128,
    threshold=0.5,  # Higher threshold = fewer predictions
    top_k=5  # Max 3 labels per article
)

# Classify all articles
results = classifier.classify_dataset(
    articles=articles,
    knowledge_graphs=knowledge_graphs
)

# Calculate metrics
metrics = calculate_metrics(results)
# Out:
# ================================================================================
# RUNNING MULTI-LABEL CLASSIFICATION
# ================================================================================
#
# ================================================================================
# INITIALIZING MULTI-LABEL GRAPH CLASSIFIER
# ================================================================================
# ✓ Initialized Node2Vec embedder (dim=128)
#
# Embedding concept knowledge graphs...
#   Embedding graph 1/21...
#   Embedding graph 6/21...
#   Embedding graph 11/21...
#   Embedding graph 16/21...
#   Embedding graph 21/21...
#
# ✓ Embedded 21 concept graphs
#   Embedding shape: (21, 128)
#   Absolute threshold: 0.5
#   Top-K limit: 3
#   Relative gap threshold: 0.15
#
# ================================================================================
# CLASSIFYING 1811 ARTICLES (MULTI-LABEL)
# ================================================================================
#
# Processing articles 0-20...
# Processing articles 20-40...
# Processing articles 40-60...
# Processing articles 60-80...
# Processing articles 80-100...
# Processing articles 100-120...
# Processing articles 120-140...
# Processing articles 140-160...
# Processing articles 160-180...
# Processing articles 180-200...
# Processing articles 200-220...
# Processing articles 220-240...
# Processing articles 240-260...
# Processing articles 260-280...
# Processing articles 280-300...
# Processing articles 300-320...
# Processing articles 320-340...
# Processing articles 340-360...
# Processing articles 360-380...
# Processing articles 380-400...
# Processing articles 400-420...
# Processing articles 420-440...
# Processing articles 440-460...
# Processing articles 460-480...
# Processing articles 480-500...
# Processing articles 500-520...
# Processing articles 520-540...
# Processing articles 540-560...
# Processing articles 560-580...
# Processing articles 580-600...
# Processing articles 600-620...
# Processing articles 620-640...
# Processing articles 640-660...
# Processing articles 660-680...
# Processing articles 680-700...
# Processing articles 700-720...
# Processing articles 720-740...
# Processing articles 740-760...
# Processing articles 760-780...
# Processing articles 780-800...
# Processing articles 800-820...
# Processing articles 820-840...
# Processing articles 840-860...
# Processing articles 860-880...
# Processing articles 880-900...
# Processing articles 900-920...
# Processing articles 920-940...
# Processing articles 940-960...
# Processing articles 960-980...
# Processing articles 980-1000...
# Processing articles 1000-1020...
# Processing articles 1020-1040...
# Processing articles 1040-1060...
# Processing articles 1060-1080...
# Processing articles 1080-1100...
# Processing articles 1100-1120...
# Processing articles 1120-1140...
# Processing articles 1140-1160...
# Processing articles 1160-1180...
# Processing articles 1180-1200...
# Processing articles 1200-1220...
# Processing articles 1220-1240...
# Processing articles 1240-1260...
# Processing articles 1260-1280...
# Processing articles 1280-1300...
# Processing articles 1300-1320...
# Processing articles 1320-1340...
# Processing articles 1340-1360...
# Processing articles 1360-1380...
# Processing articles 1380-1400...
# Processing articles 1400-1420...
# Processing articles 1420-1440...
# Processing articles 1440-1460...
# Processing articles 1460-1480...
# Processing articles 1480-1500...
# Processing articles 1500-1520...
# Processing articles 1520-1540...
# Processing articles 1540-1560...
# Processing articles 1560-1580...
# Processing articles 1580-1600...
# Processing articles 1600-1620...
# Processing articles 1620-1640...
# Processing articles 1640-1660...
# Processing articles 1660-1680...
# Processing articles 1680-1700...
# Processing articles 1700-1720...
# Processing articles 1720-1740...
# Processing articles 1740-1760...
# Processing articles 1760-1780...
# Processing articles 1780-1800...
# Processing articles 1800-1811...
#
# ✓ Classification complete!
#
# ================================================================================
# EVALUATION METRICS (Micro-Averaged)
# ================================================================================
#
# Articles evaluated: 1174
# Articles skipped (no ground truth): 637
#
# Label Distribution:
#   No labels: 39 (3.3%)
#   Single label: 0 (0.0%)
#   Multi-label: 1135 (96.7%)
#
# Aggregated Statistics:
#   True Positives (TP): 316
#   False Positives (FP): 3089
#   False Negatives (FN): 1416
#
# 📊 PERFORMANCE:
#   Precision: 0.093
#   Recall: 0.182
#   F1 Score: 0.123
#
# ================================================================================
# COMPARISON WITH PAPER BASELINES (Medical Dataset)
# ================================================================================
#   This model:           F1 = 0.123
#   GFLM-S baseline:      F1 = 0.532
#   GFLM-W baseline:      F1 = 0.530
#   SBERT:                F1 = 0.594
#   ChatGPT-3.5:          F1 = 0.606

# %%
# ============================================================================
# THREE APPROACHES TO TOPIC EMBEDDING (FIXED VERSION)
# ============================================================================

# !pip install sentence-transformers -q

import json
import numpy as np
from typing import List, Dict
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

print("✓ Imports complete\n")


class SimpleKGClassifier:
    """Classify articles by comparing KG embeddings to topic embeddings."""
    
    def __init__(self, 
                 topic_names: List[str],
                 topic_keywords: Dict[str, List[str]] = None,
                 topic_embedding_method: str = 'name_only',
                 threshold: float = 0.3):
        """
        Initialize classifier.
        
        Args:
            topic_names: List of topic names
            topic_keywords: Dictionary mapping topics to keywords
            topic_embedding_method: 'name_only', 'name_plus_keywords', or 'average_embeddings'
            threshold: Similarity threshold
        """
        self.topic_names = [t.lower() for t in topic_names]
        self.topic_keywords = topic_keywords
        self.method = topic_embedding_method
        self.threshold = threshold
        
        # Initialize SBERT model
        self.model = SentenceTransformer('all-MiniLM-L6-v2')
        
        print(f"\n{'='*80}")
        print(f"INITIALIZING CLASSIFIER - METHOD: {topic_embedding_method.upper()}")
        print(f"{'='*80}")
        print(f"Total topics: {len(self.topic_names)}")
        print(f"Threshold: {threshold}\n")
        
        # Embed topics based on method
        print(f"Embedding topics using method: {topic_embedding_method}...")
        
        if topic_embedding_method == 'name_only':
            self.topic_embeddings = self._embed_method1_name_only()
        elif topic_embedding_method == 'name_plus_keywords':
            self.topic_embeddings = self._embed_method2_name_plus_keywords()
        elif topic_embedding_method == 'average_embeddings':
            self.topic_embeddings = self._embed_method3_average_embeddings()
        else:
            raise ValueError(f"Unknown method: {topic_embedding_method}")
        
        print(f"✓ Embedded {len(self.topic_names)} topics")
        print(f"  Embedding dimension: {self.topic_embeddings.shape[1]}")
    
    def _embed_method1_name_only(self) -> np.ndarray:
        """Method 1: Embed only topic names."""
        print("  Method 1: Topic name only")
        print(f"  Example: 'phone' → embedding")
        
        embeddings = self.model.encode(self.topic_names)
        return embeddings
    
    def _embed_method2_name_plus_keywords(self) -> np.ndarray:
        """Method 2: Embed topic + keywords as concatenated text."""
        print("  Method 2: Topic + keywords as text")
        
        topic_texts = []
        for topic in self.topic_names:
            if self.topic_keywords and topic in self.topic_keywords and self.topic_keywords[topic]:
                keywords = ", ".join(self.topic_keywords[topic][:10])
                topic_text = f"{topic}: {keywords}"
            else:
                topic_text = topic
            topic_texts.append(topic_text)
        
        print(f"  Example: '{topic_texts[0][:80]}...'")
        
        embeddings = self.model.encode(topic_texts)
        return embeddings
    
    def _embed_method3_average_embeddings(self) -> np.ndarray:
        """Method 3: Average embeddings of topic name + keywords."""
        print("  Method 3: Average of topic and keyword embeddings")
        
        all_embeddings = []
        
        for topic in self.topic_names:
            # Embed topic name
            topic_emb = self.model.encode(topic)
            
            # Embed keywords if available
            if self.topic_keywords and topic in self.topic_keywords and self.topic_keywords[topic]:
                keywords = self.topic_keywords[topic][:10]
                keyword_embs = self.model.encode(keywords)
                
                # Average topic + keyword embeddings
                all_embs = np.vstack([topic_emb.reshape(1, -1), keyword_embs])
                avg_emb = np.mean(all_embs, axis=0)
            else:
                # No keywords - just use topic embedding
                avg_emb = topic_emb
            
            all_embeddings.append(avg_emb)
        
        print(f"  Example: avg(embed('phone'), embed('nokia'), embed('quality'))")
        
        return np.array(all_embeddings)
    
    def kg_to_text(self, kg_dict: Dict) -> str:
        """Convert KG to text representation."""
        entities = kg_dict.get('entities', [])
        
        if not entities:
            return ""
        
        # Just list entities
        text = ", ".join(entities[:50])
        return text
    
    def classify_article(self, article_kg: Dict) -> Dict:
        """Classify a single article."""
        kg_text = self.kg_to_text(article_kg)
        
        if not kg_text:
            return {
                'predicted_topics': [],
                'similarities': {},
                'max_similarity': 0.0
            }
        
        # Embed KG
        kg_embedding = self.model.encode(kg_text)
        
        # Compute similarities
        similarities = {}
        for i, topic_name in enumerate(self.topic_names):
            sim = cosine_similarity(
                [kg_embedding], 
                [self.topic_embeddings[i]]
            )[0][0]
            similarities[topic_name] = float(sim)
        
        # Assign topics above threshold
        predicted_topics = [
            topic for topic, sim in similarities.items() 
            if sim >= self.threshold
        ]
        
        predicted_topics = sorted(
            predicted_topics, 
            key=lambda t: similarities[t], 
            reverse=True
        )
        
        return {
            'predicted_topics': predicted_topics,
            'similarities': similarities,
            'max_similarity': max(similarities.values()) if similarities else 0.0
        }
    
    def classify_dataset(self, 
                        articles: List[Dict],
                        knowledge_graphs: List[Dict]) -> List[Dict]:
        """Classify all articles."""
        results = []
        kg_dict = {kg['id']: kg for kg in knowledge_graphs}
        
        print(f"\n{'='*80}")
        print(f"CLASSIFYING {len(knowledge_graphs)} ARTICLES")
        print(f"{'='*80}\n")
        
        for idx in range(len(knowledge_graphs)):
            if idx % 20 == 0:
                print(f"Processing articles {idx}-{min(idx+20, len(knowledge_graphs))}...")
            
            article = articles[idx] if idx < len(articles) else {}
            article_kg = kg_dict.get(idx, {'entities': [], 'relations': []})
            
            classification = self.classify_article(article_kg)
            
            result = {
                'article_id': idx,
                'predicted_topics': classification['predicted_topics'],
                'similarities': classification['similarities'],
                'max_similarity': classification['max_similarity'],
                'true_concepts': article.get('Concept', [])
            }
            
            results.append(result)
        
        print("\n✓ Classification complete!")
        return results
# Out:
# ✓ Imports complete

# %%
# ============================================================================
# TEST ALL THREE METHODS
# ============================================================================

# Get topic names
all_topic_names = list(concept_keywords.keys())

methods = {
    'name_only': 'Method 1: Topic Name Only',
    'name_plus_keywords': 'Method 2: Topic + Keywords as Text',
    'average_embeddings': 'Method 3: Average Embeddings'
}

results_comparison = {}

for method_key, method_name in methods.items():
    print(f"\n\n{'#'*80}")
    print(f"TESTING: {method_name}")
    print(f"{'#'*80}")
    
    # Initialize classifier
    classifier = SimpleKGClassifier(
        topic_names=all_topic_names,
        topic_keywords=concept_keywords,
        topic_embedding_method=method_key,
        threshold=0.3
    )
    
    # Classify
    results = classifier.classify_dataset(
        articles=articles,
        knowledge_graphs=knowledge_graphs
    )
    
    # Evaluate
    metrics = calculate_metrics_paper_style(results)
    
    # Store results
    results_comparison[method_key] = {
        'metrics': metrics,
        'results': results
    }
    
    # Save
    save_results(results, f'/kaggle/working/{method_key}_results.json')
    export_to_csv(results, f'/kaggle/working/{method_key}_results.csv')
# Out:
# ################################################################################
# TESTING: Method 1: Topic Name Only
# ################################################################################
#
# ================================================================================
# INITIALIZING CLASSIFIER - METHOD: NAME_ONLY
# ================================================================================
# Total topics: 21
# Threshold: 0.3
#
# Embedding topics using method: name_only...
#   Method 1: Topic name only
#   Example: 'phone' → embedding
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ Embedded 21 topics
#   Embedding dimension: 384
#
# ================================================================================
# CLASSIFYING 1811 ARTICLES
# ================================================================================
#
# Processing articles 0-20...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 20-40...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 40-60...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 60-80...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 80-100...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 100-120...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 120-140...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 140-160...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 160-180...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 180-200...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:05<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 200-220...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 220-240...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 240-260...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 260-280...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 280-300...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 300-320...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 320-340...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 340-360...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 360-380...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 380-400...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 400-420...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 420-440...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 440-460...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 460-480...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 480-500...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 500-520...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 520-540...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 540-560...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 560-580...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 580-600...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 600-620...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 620-640...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 640-660...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 660-680...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 680-700...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 700-720...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 720-740...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 740-760...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 760-780...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 780-800...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 800-820...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 820-840...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 840-860...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 860-880...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 880-900...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 900-920...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 920-940...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 940-960...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 960-980...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 980-1000...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1000-1020...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1480-1500...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1500-1520...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1520-1540...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1540-1560...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1560-1580...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1580-1600...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1600-1620...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1620-1640...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1640-1660...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1660-1680...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1680-1700...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1700-1720...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1720-1740...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1740-1760...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1760-1780...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1780-1800...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing articles 1800-1811...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ✓ Classification complete!
#
# ================================================================================
# EVALUATION METRICS (Paper's Methodology)
# ================================================================================
#
# Articles evaluated: 1174
# Articles skipped (no ground truth): 637
#
# Aggregated Statistics:
#   True Positives (TP): 690
#   False Positives (FP): 1934
#   False Negatives (FN): 1042
#
# 📊 MICRO-AVERAGED METRICS:
#   Precision: 0.263
#   Recall: 0.398
#   F1 Score: 0.317
#
# ✓ Results saved to /kaggle/working/average_embeddings_results.json
# ✓ CSV exported to /kaggle/working/average_embeddings_results.csv

# %%
# ============================================================================
# FINAL COMPARISON OF ALL METHODS
# ============================================================================

print(f"\n\n{'='*80}")
print("FINAL COMPARISON: ALL METHODS")
print(f"{'='*80}\n")

comparison_df = pd.DataFrame({
    'Method': [
        'Method 1: Name Only',
        'Method 2: Name + Keywords Text',
        'Method 3: Average Embeddings',
        'LLM Reasoning (baseline)',
        'Paper ChatGPT (baseline)'
    ],
    'F1 Score': [
        results_comparison['name_only']['metrics']['f1_score'],
        results_comparison['name_plus_keywords']['metrics']['f1_score'],
        results_comparison['average_embeddings']['metrics']['f1_score'],
        0.818,
        0.606
    ],
    'Precision': [
        results_comparison['name_only']['metrics']['precision'],
        results_comparison['name_plus_keywords']['metrics']['precision'],
        results_comparison['average_embeddings']['metrics']['precision'],
        0.719,
        '-'
    ],
    'Recall': [
        results_comparison['name_only']['metrics']['recall'],
        results_comparison['name_plus_keywords']['metrics']['recall'],
        results_comparison['average_embeddings']['metrics']['recall'],
        0.948,
        '-'
    ]
})

print(comparison_df.to_string(index=False))

# Find best method
best_method = max(results_comparison.items(), key=lambda x: x[1]['metrics']['f1_score'])
print(f"\n{'='*80}")
print(f"🏆 BEST METHOD: {methods[best_method[0]]}")
print(f"   F1 Score: {best_method[1]['metrics']['f1_score']:.3f}")
print(f"{'='*80}")
# Out:
# ================================================================================
# FINAL COMPARISON: ALL METHODS
# ================================================================================
#
#                         Method  F1 Score Precision    Recall
#            Method 1: Name Only  0.280011  0.262785  0.299654
# Method 2: Name + Keywords Text  0.420282  0.396217   0.44746
#   Method 3: Average Embeddings  0.316804  0.262957  0.398383
#       LLM Reasoning (baseline)  0.818000     0.719     0.948
#       Paper ChatGPT (baseline)  0.606000         -         -
#
# ================================================================================
# 🏆 BEST METHOD: Method 2: Topic + Keywords as Text
#    F1 Score: 0.420
# ================================================================================
